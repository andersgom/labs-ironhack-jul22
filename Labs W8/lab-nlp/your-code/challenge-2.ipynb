# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide.
#
# Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
# your code here
import pandas as pd

text = pd.read_csv("tweets.csv", encoding='latin1').sample(20000)
text.columns = ['target','id','date','flag','user','text']
text.head(3)
# Out:
#          target          id                          date      flag  \
# 1209882       4  1988980785  Sun May 31 23:58:07 PDT 2009  NO_QUERY
# 463391        0  2174910290  Sun Jun 14 23:36:28 PDT 2009  NO_QUERY
# 1199146       4  1985264432  Sun May 31 16:45:52 PDT 2009  NO_QUERY
#
#                user                                               text
# 1209882  powerlevel  power Advertisement: how do you guys handle fa...
# 463391      Ayizzle  @bigced iounno. just food. burgers, fries, stu...
# 1199146   Krissette  @johnnybeane Awww! We miss you too Johnny! Let...

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# your code here
from helper_funcs import *

txtlist = text['text']
txtlist

txtclean = [clean_up(tw) for tw in txtlist]
txtclean

txt_tkn = [tokenize(tw) for tw in txtclean]
txt_tkn
# Out:
# [['power',
#   'advertisement',
#   'how',
#   'do',
#   'you',
#   'guys',
#   'handle',
#   'fax',
#   'i',
#   'want',
#   'to',
#   'receive',
#   'them',
#   'via',
#   'email',
#   'no',
#   'hassle',
#   'anyone',
#   'tried',
#   'myfax',
#   'is',
#   'gd',
#   'lfd'],
#  ['bigced',
#   'iounno',
#   'just',
#   'food',
#   'burgers',
#   'fries',
#   'stuff',
#   'that',
#   'i',
#   'shouldn',
#   't',
#   'be',
#   'eating'],
#  ['johnnybeane',
#   'awww',
#   'we',
#   'miss',
#   'you',
#   'too',
#   'johnny',
#   'let',
#   's',
#   'go',
#   'get',
#   'some',
#   'food'],
#  ['alisonmf',
#   'sorry',
#   'to',
#   'hear',
#   'about',
#   'your',
#   'parking',
#   'troubles',
#   'we',
#   'missed',
#   'ya'],
#  ['oh',
#   'yay',
#   'i',
#   'love',
#   'hotel',
#   'cable',
#   'up',
#   'next',
#   'harry',
#   'potter',
#   'and',
#   'the',
#   'goblet',
#   'of',
#   'fire',
#   'or',
#   'yes',
#   'man',
#   'votes'],
#  ['steve',
#   'jobs',
#   'called',
#   'quot',
#   'perishable',
#   'asset',
#   'quot',
#   'apple',
#   'by',
#   'npr',
#   'cold',
#   'way',
#   'refer',
#   'some',
#   'who',
#   's',
#   'been',
#   'so',
#   'sick',
#   'myloc',
#   'me',
#   'amf'],
#  ['piccadillyman',
#   'feeling',
#   'the',
#   'same',
#   'bruv',
#   'feeling',
#   'hungover',
#   'and',
#   'a',
#   'swimming',
#   'pool',
#   'should',
#   'never',
#   'team',
#   'up'],
#  ['lots',
#   'of',
#   'talk',
#   'of',
#   'the',
#   'kidnapping',
#   'unbelievable',
#   'that',
#   'something',
#   'like',
#   'that',
#   'happens',
#   'here',
#   'used',
#   'to',
#   'be',
#   'a',
#   'safe',
#   'place',
#   'but',
#   'isnt',
#   't',
#   'quite',
#   'so'],
#  ['i', 'forgot', 'my', 'cellphone', 'at', 'my', 'grandmass'],
#  ['nathanbowers',
#   'where',
#   's',
#   'she',
#   'gon',
#   'na',
#   'go',
#   'after',
#   'google',
#   'right'],
#  ['jammin',
#   'why',
#   'don',
#   't',
#   'you',
#   'ever',
#   'do',
#   'illegal',
#   'stuff',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'night',
#   'with',
#   'me'],
#  ['hurricane',
#   'festival',
#   'i',
#   'd',
#   'love',
#   'to',
#   'go',
#   'there',
#   'but',
#   'my',
#   'mother',
#   'just',
#   'doesn',
#   't',
#   'let',
#   'me'],
#  ['what', 'the', 'heck', 'is', 'this'],
#  ['ms_srod', 'shouldn', 't', 'you', 'know', 'your', 'national', 'holidays'],
#  ['katdish', 'as', 'far', 'as', 'i', 'can', 'tell'],
#  ['oncgnt',
#   'yuppieee',
#   'doodoooo',
#   'haha',
#   'yeh',
#   'enjoy',
#   'your',
#   'rest',
#   'of',
#   'your',
#   'week',
#   'i',
#   'seeyaaaa',
#   'soon'],
#  ['brotherelijah',
#   'hahah',
#   'i',
#   've',
#   'been',
#   'dying',
#   'for',
#   'one',
#   'of',
#   'those',
#   'slushies',
#   'for',
#   'years',
#   'but',
#   'ive',
#   'come',
#   'to',
#   'the',
#   'conclusion',
#   'that',
#   'sonic',
#   'is',
#   'not',
#   'a',
#   'real',
#   'place'],
#  ['im',
#   'so',
#   'tired',
#   'im',
#   'back',
#   'from',
#   'vaca',
#   'and',
#   'i',
#   'lost',
#   'my',
#   'cladaw',
#   'ring',
#   'and',
#   'busted',
#   'my',
#   'finger',
#   'but',
#   'im',
#   'happy',
#   'im',
#   'home'],
#  ['epic', 'fail', 'at', 'watching', 'eurovision'],
#  ['waking', 'up', 'to', 'the', 'mexico', 'heat'],
#  ['grreenlikejuly', 'doubly', 'good', 'plan', 'get', 'a', 'good', 'seat'],
#  ['gozzipgangster',
#   'i',
#   'll',
#   'pray',
#   'with',
#   'u',
#   'h',
#   'amp',
#   'm',
#   'isn',
#   't',
#   'that',
#   'fast',
#   'ask',
#   'my',
#   'daughter'],
#  ['jacosta',
#   'awesome',
#   'with',
#   'more',
#   'person',
#   'driving',
#   'defensively',
#   'on',
#   'the',
#   'roads',
#   'there',
#   's',
#   'more',
#   'room',
#   'me',
#   'drive',
#   'offensively',
#   'thanks',
#   'for',
#   'ur',
#   'help'],
#  ['tonfue',
#   'hey',
#   'ther',
#   'hun',
#   'lt',
#   'sorry',
#   'but',
#   'i',
#   'gtg',
#   'im',
#   'going',
#   'shopping',
#   'haha',
#   'well',
#   'ill',
#   'tweet',
#   'u',
#   'later',
#   'go',
#   'back',
#   'on',
#   'later',
#   'tonite',
#   'bye'],
#  ['joecolumbo',
#   'good',
#   'afternoon',
#   'well',
#   'morning',
#   'here',
#   'how',
#   's',
#   'it',
#   'saturday'],
#  ['melanieyost',
#   'i',
#   'made',
#   'choc',
#   'chip',
#   'cookies',
#   'yesterday',
#   'before',
#   'seeing',
#   'your',
#   'recipe',
#   'but',
#   'already',
#   'planning',
#   'on',
#   'making',
#   'ur',
#   'brownies'],
#  ['wife', 'is', 'sick', 'summer', 'cold'],
#  ['joeymcintyre',
#   'bee',
#   'girl',
#   'here',
#   'i',
#   'can',
#   't',
#   'wait',
#   'to',
#   'see',
#   'ya',
#   'buddy',
#   'amp',
#   'i',
#   'll',
#   'try',
#   'to',
#   'get',
#   'my',
#   'book',
#   'donations',
#   'to',
#   'every',
#   'show',
#   'i',
#   'do',
#   'hope',
#   'u',
#   'are',
#   'having',
#   'fun'],
#  ['whoa',
#   'whoa',
#   'whoa',
#   'typ',
#   'tyler',
#   'has',
#   'a',
#   'better',
#   'following',
#   'than',
#   'me',
#   'but',
#   'm',
#   'jhappy',
#   'for',
#   'the',
#   'cause'],
#  ['fakerparis', 'boo', 'i', 'got', 'rained', 'out', 'at', 'the', 'beach'],
#  ['still', 'hurt', 'my', 'leg'],
#  ['don',
#   't',
#   'forget',
#   'that',
#   'tomorrow',
#   'tokio',
#   'hotel',
#   's',
#   'oficial',
#   'website',
#   'will',
#   'be',
#   'back',
#   'check',
#   'it',
#   'www',
#   'tokiohotel'],
#  ['i',
#   'have',
#   'a',
#   'dick',
#   'on',
#   'my',
#   'back',
#   'courtesy',
#   'of',
#   'steph',
#   'and',
#   'kayla'],
#  ['a', 'little', 'bit', 'of', 'good', 'news'],
#  ['my',
#   'baby',
#   'is',
#   'sick',
#   'she',
#   's',
#   'cuddling',
#   'with',
#   'a',
#   'pink',
#   'unicorn',
#   'twitpic',
#   'com',
#   'qyw'],
#  ['off',
#   'to',
#   'work',
#   'overnighter',
#   'sleep',
#   'will',
#   'come',
#   'on',
#   'tuesday'],
#  ['i', 'am', 'not', 'posh', 'enough', 'for', 'my', 'hotel'],
#  ['have',
#   'to',
#   'quot',
#   'freshen',
#   'quot',
#   'my',
#   'eyes',
#   'every',
#   'hour',
#   'what',
#   'a',
#   'bother'],
#  ['just',
#   'booked',
#   'our',
#   'holiday',
#   'just',
#   'a',
#   'shame',
#   'i',
#   'can',
#   't',
#   'take',
#   'my',
#   'baby',
#   'cos',
#   'she',
#   'is',
#   'on',
#   'holiday',
#   'with',
#   'her',
#   'mum',
#   'at',
#   'the',
#   'same',
#   'time',
#   'and',
#   'she',
#   'got',
#   'in',
#   'st'],
#  ['why',
#   'won',
#   't',
#   'multimedia',
#   'messages',
#   'work',
#   'on',
#   'my',
#   'iphone',
#   'despite',
#   'software'],
#  ['mr_marty', 'naa', 'it', 'doesn', 't'],
#  ['who',
#   'da',
#   'fuck',
#   'u',
#   'be',
#   'bitch',
#   'ya',
#   'know',
#   'me',
#   'i',
#   'm',
#   'sumthin',
#   'like',
#   'a',
#   'pimp',
#   'uh',
#   'uh',
#   'uh',
#   'what'],
#  ['princerug', 'just', 'seen', 'u', 'following', 'me', 'thanks', 'x'],
#  ['helenaa_s',
#   'weeks',
#   'just',
#   'i',
#   'can',
#   't',
#   'waiiiiiiit',
#   'p',
#   'to',
#   'see',
#   'them',
#   'd',
#   'amp',
#   'jb',
#   'xo'],
#  ['has', 'so', 'much', 'to', 'blog', 'but', 'has', 'no', 'time', 'to'],
#  ['man', 'im', 'so', 'bored', 'and', 'i', 'feel', 'sick', 'ugh'],
#  ['laura_eyedea',
#   'excellent',
#   'well',
#   'i',
#   'm',
#   'going',
#   'all',
#   'day',
#   'on',
#   'thursday',
#   'so',
#   'hopefully',
#   'see',
#   'you',
#   'there'],
#  ['getting',
#   'ready',
#   'to',
#   'brave',
#   'the',
#   'port',
#   'a',
#   'potty',
#   'at',
#   'the',
#   'soccer',
#   'tryouts',
#   'wish',
#   'me',
#   'luck'],
#  ['i',
#   'am',
#   'up',
#   'to',
#   'and',
#   'twitter',
#   'won',
#   't',
#   'let',
#   'me',
#   'follow',
#   'any',
#   'more'],
#  ['not',
#   'going',
#   'to',
#   'maine',
#   'staying',
#   'home',
#   'with',
#   'the',
#   'mom',
#   's',
#   'for',
#   'mothers',
#   'day',
#   'hopefully',
#   'we',
#   'will',
#   'go',
#   'out',
#   'and',
#   'do',
#   'something',
#   'fun'],
#  ['jordanknight',
#   'i',
#   'm',
#   'ready',
#   'iâ',
#   'm',
#   'always',
#   'ready',
#   'but',
#   'iâ',
#   'm',
#   'in',
#   'spain'],
#  ['joshuahake',
#   'bad',
#   'friend',
#   'that',
#   'i',
#   'am',
#   'i',
#   'didn',
#   't',
#   'even',
#   'know',
#   'happy',
#   'birthday',
#   'joshua'],
#  ['good', 'night', 'sweet', 'dreams'],
#  ['ughh',
#   'been',
#   'sick',
#   'for',
#   'the',
#   'past',
#   'two',
#   'day',
#   'and',
#   'it',
#   'sucks',
#   'the',
#   'weather',
#   'here',
#   'is',
#   'sooo',
#   'nice',
#   'but',
#   'can',
#   't',
#   'enjoy',
#   'it',
#   'stuck',
#   'inside'],
#  ['pseud',
#   'random',
#   'wow',
#   'u',
#   'really',
#   'got',
#   'hooked',
#   'didnt',
#   'you',
#   'lol',
#   'want',
#   'another'],
#  ['my', 'volume', 'don', 't', 'work'],
#  ['emily_c',
#   'getting',
#   'knocked',
#   'up',
#   'will',
#   'do',
#   'that',
#   'to',
#   'you',
#   'hates',
#   'it',
#   'i',
#   'll',
#   'be',
#   'your',
#   'surrogate',
#   'daddyyyy'],
#  ['i', 'want', 'taking', 'back', 'sunday', 's', 'new', 'album', 'please'],
#  ['backstreetboys',
#   'oh',
#   'no',
#   'poor',
#   'aj',
#   'one',
#   'of',
#   'u',
#   'better',
#   'give',
#   'me',
#   'a',
#   'lift',
#   'then'],
#  ['shoq',
#   'it',
#   'wasn',
#   't',
#   'widely',
#   'reported',
#   'we',
#   'try',
#   'tocatch',
#   'the',
#   'sneaky',
#   'little',
#   'things',
#   'that',
#   'slip',
#   'thru',
#   'the',
#   'cracks'],
#  ['gurpsk',
#   'but',
#   'you',
#   've',
#   'admitted',
#   'it',
#   'in',
#   'the',
#   'past',
#   'just',
#   'listening',
#   'to',
#   'ek',
#   'ladki',
#   'by',
#   'bally',
#   'sagoo',
#   'memories'],
#  ['my',
#   'poor',
#   'boys',
#   'are',
#   'sick',
#   'it',
#   's',
#   'horrible',
#   'seeing',
#   'your',
#   'kids',
#   'suffer',
#   'amp',
#   'not',
#   'being',
#   'able',
#   'to',
#   'make',
#   'them',
#   'feel',
#   'better',
#   'instantly'],
#  ['cramps', 'don', 't', 'allow', 'me', 'to', 'be', 'funny'],
#  ['cleaning', 'room'],
#  ['ice',
#   'cream',
#   'is',
#   'really',
#   'really',
#   'good',
#   'except',
#   'that',
#   'it',
#   's',
#   'cold',
#   'in',
#   'the',
#   'office',
#   'today',
#   'and',
#   'i',
#   'm',
#   'freezing'],
#  ['immortal_flower', 'yes'],
#  ['mosquitoes', 'attacked', 'the', 'shit', 'out', 'of', 'me', 'last', 'night'],
#  ['of',
#   'the',
#   'logan',
#   'sisters',
#   'in',
#   'the',
#   'garden',
#   'enjoyin',
#   'the',
#   'sunshine'],
#  ['can',
#   'somebody',
#   'please',
#   'calm',
#   'me',
#   'down',
#   'from',
#   'this',
#   'unpleasant',
#   'thoughts'],
#  ['tracylatz',
#   'thanks',
#   'if',
#   'anybody',
#   'commented',
#   'on',
#   'my',
#   'interview',
#   'liaracovert',
#   'is',
#   'asleep',
#   'i',
#   'believe',
#   'in',
#   'aus',
#   'but',
#   'she',
#   'will',
#   'approve',
#   'them',
#   'soon'],
#  ['cosmohavanese',
#   'ok',
#   'ok',
#   'i',
#   'get',
#   'it',
#   'now',
#   'color',
#   'me',
#   'blushed',
#   'with',
#   'embarrassment',
#   'i',
#   'll',
#   'have',
#   'to',
#   'donate',
#   'to',
#   'make',
#   'up',
#   'for',
#   'it',
#   'pussycatisland'],
#  ['pkgulati',
#   'lol',
#   'i',
#   'm',
#   'gna',
#   'be',
#   'there',
#   'too',
#   'that',
#   's',
#   'why',
#   'i',
#   'was',
#   'asking'],
#  ['no', 'iphone', 'update', 'yet', 'where', 'is', 'it'],
#  ['haha',
#   'score',
#   'woke',
#   'up',
#   'before',
#   'the',
#   'post',
#   'man',
#   'oh',
#   'god',
#   'and',
#   'its',
#   'lovely',
#   'even',
#   'better',
#   'i',
#   'will',
#   'do',
#   'my',
#   'ff',
#   'later'],
#  ['naina',
#   'they',
#   'are',
#   'ridiculously',
#   'expensive',
#   'here',
#   'so',
#   'as',
#   'always',
#   'it',
#   's',
#   'probably',
#   'more',
#   'so',
#   'there',
#   'you',
#   'can',
#   'trade',
#   'in',
#   'your',
#   'home',
#   'for',
#   'one',
#   'i',
#   'almost',
#   'have'],
#  ['another',
#   'gorgeous',
#   'day',
#   'to',
#   'nice',
#   'to',
#   'be',
#   'stuck',
#   'in',
#   'front',
#   'of',
#   'the',
#   'pc'],
#  ['damn',
#   'it',
#   'i',
#   'left',
#   'my',
#   'wallet',
#   'home',
#   'today',
#   'i',
#   'am',
#   'gon',
#   'na',
#   'die',
#   'from',
#   'starvation'],
#  ['myweakness', 'cuddles', 'and', 'teddys', 'and', 'animals'],
#  ['finals',
#   'in',
#   'a',
#   'couple',
#   'hours',
#   'ugh',
#   'really',
#   'not',
#   'ready',
#   'for',
#   'this'],
#  ['finally',
#   'done',
#   'with',
#   'moving',
#   'now',
#   'i',
#   'need',
#   'to',
#   'unpack',
#   'dinner',
#   'with',
#   'the',
#   'ladies',
#   'one',
#   'last',
#   'time',
#   'tonight',
#   'before',
#   'everything',
#   'changes'],
#  ['thelastressort', 'you', 'are', 'quite', 'welcome', 'enjoy'],
#  ['jessseemaka',
#   'oh',
#   'okay',
#   'awesome',
#   'i',
#   'wud',
#   'love',
#   'to',
#   'visit',
#   'laguna',
#   'one',
#   'day',
#   'it',
#   'looks',
#   'beautiful',
#   'there',
#   'are',
#   'u',
#   'still',
#   'friends',
#   'wit',
#   'kristin',
#   'and',
#   'others',
#   'x'],
#  ['steel',
#   'train',
#   'tour',
#   'dates',
#   'are',
#   'up',
#   'but',
#   'none',
#   'in',
#   'texas',
#   'right',
#   'now',
#   'fuck'],
#  ['mattmehaffey', 'great', 'enjoy'],
#  ['alanwardle', 'lad', 'who', 'won', 'the', 'anyforty', 'comp'],
#  ['i',
#   'loved',
#   'loved',
#   'loved',
#   'that',
#   'progressive',
#   'had',
#   'a',
#   'booth',
#   'at',
#   'pride',
#   'this',
#   'year',
#   'so',
#   'proud'],
#  ['i',
#   'think',
#   'my',
#   'best',
#   'friend',
#   'is',
#   'spamming',
#   'me',
#   'on',
#   'purpose',
#   'u',
#   'bastard'],
#  ['i',
#   'm',
#   'so',
#   'fucking',
#   'tired',
#   'starting',
#   'to',
#   'get',
#   'a',
#   'headache',
#   'aswell',
#   'and',
#   'now',
#   'at',
#   'like',
#   'the',
#   'sun',
#   'starts',
#   'to',
#   'shine',
#   'hours',
#   'late',
#   'fucktard'],
#  ['suzeormanshow',
#   'suze',
#   'why',
#   'are',
#   'your',
#   'tweets',
#   'all',
#   'within',
#   'quotation',
#   'marks',
#   'tagged',
#   'etc',
#   'is',
#   'someone',
#   'twittering',
#   'for',
#   'you',
#   'i',
#   'sure',
#   'hope',
#   'not'],
#  ['portercarly', 'hiii', 'seeester'],
#  ['omfg',
#   'my',
#   'computer',
#   'is',
#   'so',
#   'retarded',
#   'but',
#   'this',
#   'time',
#   'best',
#   'buy',
#   'is',
#   'helping'],
#  ['ayenami', 'adampark', 'victory', 'will', 'be', 'mine', 'daddy'],
#  ['on',
#   'the',
#   'swings',
#   'on',
#   'the',
#   'park',
#   'i',
#   'need',
#   'to',
#   'calm',
#   'down',
#   'times',
#   'like',
#   'these',
#   'i',
#   'wish',
#   'my',
#   'besties',
#   'lived',
#   'near',
#   'by'],
#  ['diegoandres',
#   'thank',
#   'you',
#   'for',
#   'having',
#   'me',
#   'and',
#   'jessicacorbett',
#   'over',
#   'tell',
#   'sara',
#   'hello',
#   'and',
#   'we',
#   'all',
#   'must',
#   'get',
#   'together',
#   'again',
#   'myloc',
#   'me',
#   'mcq'],
#  ['caseyore',
#   'well',
#   'when',
#   'i',
#   'have',
#   'to',
#   'move',
#   'again',
#   'i',
#   'know',
#   'where',
#   'i',
#   'am',
#   'going',
#   'yay',
#   'lol'],
#  ['went',
#   'to',
#   'sleep',
#   'with',
#   'a',
#   'man',
#   'in',
#   'my',
#   'bed',
#   'woke',
#   'up',
#   'without',
#   'one'],
#  ['stephaniepratt',
#   'steph',
#   'i',
#   'm',
#   'so',
#   'glad',
#   'that',
#   'you',
#   'are',
#   'reaching',
#   'out',
#   'to',
#   'help',
#   'people',
#   'will',
#   'these',
#   'problems',
#   'my',
#   'aunt',
#   'amp',
#   'uncle',
#   'passed',
#   'away',
#   'from',
#   'them'],
#  ['adamortega',
#   'lmfao',
#   'her',
#   'eyebrows',
#   'are',
#   'a',
#   'bit',
#   'thick',
#   'for',
#   'me',
#   'but',
#   'not',
#   'bad',
#   'he',
#   'looks',
#   'kinda',
#   'ragged',
#   'still',
#   'tons',
#   'better',
#   'looking',
#   'then',
#   'bc',
#   'though'],
#  ['campblsoupgrl',
#   'son',
#   'oliver',
#   'just',
#   'peed',
#   'on',
#   'me',
#   'not',
#   'okay',
#   'dude'],
#  ['countrycutie',
#   'yeah',
#   'it',
#   's',
#   'so',
#   'sad',
#   'but',
#   'it',
#   's',
#   'really',
#   'good',
#   'can',
#   't',
#   'wait',
#   'till',
#   'it',
#   'comes',
#   'out',
#   'on',
#   'oh',
#   'btw',
#   'have',
#   'u',
#   'read',
#   'the',
#   'series'],
#  ['raining',
#   'outside',
#   'have',
#   'to',
#   'do',
#   'some',
#   'work',
#   'for',
#   'latin',
#   'before',
#   'going',
#   'to',
#   'university'],
#  ['just',
#   'had',
#   'a',
#   'blonde',
#   'moment',
#   'ughk',
#   'paint',
#   'brandon',
#   'rug',
#   'sorry',
#   'rug'],
#  ['goodbye', 'amp', 'congrats', 'class', 'of'],
#  ['realdmitchell',
#   'thought',
#   'wossy',
#   'was',
#   'a',
#   'bit',
#   'a',
#   'patronizing',
#   'to',
#   'you',
#   'when',
#   'i',
#   'watched',
#   'the',
#   'repeat',
#   'last',
#   'night'],
#  ['the',
#   'vending',
#   'machine',
#   's',
#   'broken',
#   'and',
#   'i',
#   'wanted',
#   'chocolate'],
#  ['saw', 'a', 'guy', 'with', 'a', 'jaft', 'shirt', 'at', 'centralen'],
#  ['sarahstephaniex',
#   'i',
#   'know',
#   'would',
#   'be',
#   'amazing',
#   'lt',
#   'we',
#   'live',
#   'too',
#   'far',
#   'apart',
#   'boo',
#   'haa'],
#  ['stacia',
#   'again',
#   'there',
#   's',
#   'a',
#   'special',
#   'guest',
#   'in',
#   'the',
#   'studio',
#   'my',
#   'year',
#   'old',
#   'sister',
#   'is',
#   'in',
#   'town',
#   'and',
#   'she',
#   'got',
#   'up',
#   'early',
#   'to',
#   'come',
#   'to',
#   'work',
#   'with',
#   'me'],
#  ['ginabertsos',
#   'no',
#   'flu',
#   'and',
#   'the',
#   'worst',
#   'migraine',
#   'ever',
#   'i',
#   'have',
#   'mersyndol',
#   'forte',
#   'thats',
#   'the',
#   'only',
#   'reason',
#   'i',
#   'can',
#   'open',
#   'my',
#   'eyes'],
#  ['on', 'the', 'l', 'just', 'as', 'dirty', 'as', 'the', 'bus'],
#  ['had',
#   'fun',
#   'at',
#   'my',
#   'dad',
#   's',
#   'birthday',
#   'at',
#   'the',
#   'insistence',
#   'of',
#   'my',
#   'mom',
#   'i',
#   'did',
#   'one',
#   'of',
#   'my',
#   'multi',
#   'slide',
#   'presentations',
#   'about',
#   'him',
#   'lots',
#   'of',
#   'fun'],
#  ['i', 'really', 'think', 'that', 'i', 'should', 'make', 'it', 'up'],
#  ['obox',
#   'good',
#   'stuff',
#   'i',
#   'have',
#   'some',
#   'seriously',
#   'cool',
#   'clients',
#   'too',
#   'tg',
#   'for',
#   'that',
#   'huh'],
#  ['jonasbrothers',
#   'woah',
#   'nick',
#   'ur',
#   'done',
#   'w',
#   'school',
#   'wow',
#   'the',
#   'risk',
#   'of',
#   'sounding',
#   'weird',
#   'sketchy',
#   'i',
#   'm',
#   'so',
#   'proud',
#   'of',
#   'u',
#   'u',
#   'guys',
#   'r',
#   'great',
#   'influences'],
#  ['is',
#   'a',
#   'mom',
#   'going',
#   'back',
#   'to',
#   'school',
#   'and',
#   'watching',
#   'my',
#   'gpa',
#   'drop',
#   'what',
#   's',
#   'the',
#   'best',
#   'way',
#   'to',
#   'get',
#   'your',
#   'focus',
#   'back'],
#  ['kenyagen',
#   'congrats',
#   'we',
#   'now',
#   'have',
#   'a',
#   'full',
#   'coverage',
#   'of',
#   'smartphones',
#   'on',
#   'the',
#   'office'],
#  ['first', 'football', 'match', 'i', 've', 'been', 'to', 'was', 'fun'],
#  ['listening', 'to', 'adele', 'beach', 'tomorrow'],
#  ['gingsquared', 'i', 'was', 'just', 'listening', 'to', 'kylie', 'minogue'],
#  ['perezhilton', 'that', 's', 'terrible'],
#  ['no',
#   'art',
#   'for',
#   'a',
#   'couple',
#   'of',
#   'days',
#   'if',
#   'not',
#   'a',
#   'week',
#   'do',
#   'to',
#   'old',
#   'hockey',
#   'injury',
#   'back',
#   'i',
#   'am',
#   'out',
#   'for',
#   'the',
#   'count',
#   'till',
#   'the',
#   'pain',
#   'subside'],
#  ['its',
#   'supposed',
#   'to',
#   'be',
#   'nice',
#   'tomorrow',
#   'again',
#   'but',
#   'im',
#   'going',
#   'to',
#   'my',
#   'grans',
#   'so',
#   'wont',
#   'be',
#   'able',
#   'to',
#   'enjoy',
#   't'],
#  ['we', 'geeks', 'are', 'sexy', 'bit', 'ly', 't'],
#  ['dill', 'pickle', 'pringles', 'freakin', 'amazing'],
#  ['yellowsphere',
#   'schweet',
#   'we',
#   'have',
#   'the',
#   'mics',
#   'just',
#   'not',
#   'enough',
#   'inputs',
#   'yet',
#   'anyway'],
#  ['pink',
#   'get',
#   'h',
#   'amp',
#   'h',
#   'to',
#   'tour',
#   'the',
#   'us',
#   'with',
#   'u',
#   'i',
#   'hear',
#   'u',
#   'have',
#   'connections',
#   'lol'],
#  ['my',
#   'shit',
#   'is',
#   'smoother',
#   'than',
#   'persian',
#   'rugs',
#   'cashmere',
#   'chromosomes'],
#  ['sarahkathrina', 'good', 'afternoon', 'ahahaha'],
#  ['yaniv', 'thnks', 'for', 'the', 'follow'],
#  ['just',
#   'got',
#   'a',
#   'haircut',
#   'and',
#   'is',
#   'getting',
#   'sushi',
#   'today',
#   'is',
#   'a',
#   'good',
#   'day',
#   'my',
#   'head',
#   'feels',
#   'lighter'],
#  ['haveyouever',
#   'wanted',
#   'to',
#   'give',
#   'something',
#   'special',
#   'to',
#   'ur',
#   'father',
#   'on',
#   'his',
#   'day',
#   'but',
#   'u',
#   'have',
#   'done',
#   'all'],
#  ['tubelord', 'i', 'didn', 't', 'get', 'to', 'download', 'that', 'song'],
#  ['i',
#   'love',
#   'rockstars',
#   'so',
#   'much',
#   'i',
#   'just',
#   'wish',
#   'that',
#   'they',
#   'were',
#   'queer',
#   'bashers',
#   'ugh'],
#  ['alithealien',
#   'you',
#   'are',
#   'not',
#   'alone',
#   'i',
#   'm',
#   'sat',
#   'at',
#   'the',
#   'computer',
#   'not',
#   'near',
#   'telly',
#   'and',
#   'wife',
#   'is',
#   'playing',
#   'dido',
#   'songs',
#   'as',
#   'i',
#   'trundle',
#   'round',
#   'the',
#   'net'],
#  ['sprained',
#   'her',
#   'ankle',
#   'in',
#   'a',
#   'game',
#   'of',
#   'tag',
#   'at',
#   'the',
#   'beginning',
#   'of',
#   'class',
#   'tonight'],
#  ['today',
#   'is',
#   'the',
#   'day',
#   'p',
#   'nk',
#   'realises',
#   'i',
#   'am',
#   'the',
#   'one',
#   'for',
#   'her',
#   'leaving',
#   'in',
#   'hours',
#   'fuckkkkk'],
#  ['man', 'today', 'is', 'a', 'rough', 'day', 'and', 'its', 'only', 'am'],
#  ['waiting', 'for', 'landlord', 'to', 'come', 'see', 'about', 'our', 'shower'],
#  ['dontcallmebones',
#   'hahahahha',
#   'thats',
#   'right',
#   'i',
#   'know',
#   'i',
#   'like',
#   'eating',
#   'weird',
#   'things'],
#  ['bleed_purple',
#   'twice',
#   '_',
#   'armans',
#   'starting',
#   'at',
#   'soo',
#   'you',
#   'never',
#   'know'],
#  ['wo',
#   'ah',
#   'cool',
#   'sounds',
#   'good',
#   'i',
#   'll',
#   'keep',
#   'alert',
#   'for',
#   'next',
#   'time'],
#  ['happy',
#   'mother',
#   's',
#   'day',
#   'to',
#   'all',
#   'you',
#   'mommas',
#   'we',
#   'spent',
#   'the',
#   'day',
#   'working',
#   'on',
#   'the',
#   'chicken',
#   'coop',
#   'surprise'],
#  ['eating',
#   'dinner',
#   'and',
#   'watching',
#   'csi',
#   'with',
#   'my',
#   'mom',
#   'great',
#   'day',
#   'today'],
#  ['dang',
#   'wish',
#   'i',
#   'was',
#   'at',
#   'e',
#   'right',
#   'now',
#   'looks',
#   'like',
#   'so',
#   'much',
#   'fun',
#   'instead',
#   'i',
#   'm',
#   'stuck',
#   'workin',
#   'myloc',
#   'me',
#   'k'],
#  ['burnt', 'my', 'tongue'],
#  ['raining',
#   'cold',
#   'working',
#   'morella',
#   'st',
#   'this',
#   'morning',
#   'better',
#   'dig',
#   'out',
#   'my',
#   'gumboots'],
#  ['has',
#   'been',
#   'waiting',
#   'months',
#   'for',
#   'papa',
#   'chanos',
#   'carne',
#   'asada',
#   'oh',
#   'happy',
#   'day'],
#  ['god',
#   'i',
#   'm',
#   'so',
#   'annoyed',
#   'that',
#   'i',
#   'have',
#   'to',
#   'do',
#   'this',
#   'science',
#   'project',
#   'right',
#   'now',
#   'argh',
#   'i',
#   'would',
#   'have',
#   'been',
#   'posting',
#   'on',
#   'my',
#   'blog',
#   'but',
#   'no',
#   'rrrr'],
#  ['kidcalloway', 'sowwy', 'i', 'had', 'get', 'up', 'at', 'this', 'morning'],
#  ['im',
#   'tired',
#   'of',
#   'these',
#   'hussie',
#   'bscott',
#   'luvnless',
#   'doing',
#   'hoodrat',
#   'things',
#   'without',
#   'me',
#   'when',
#   'i',
#   'come',
#   'in',
#   'town',
#   'dont',
#   'nobody',
#   'wan',
#   'na',
#   'do',
#   'anything'],
#  ['so',
#   'how',
#   'do',
#   'we',
#   'bring',
#   'some',
#   'life',
#   'to',
#   'our',
#   'new',
#   'french',
#   'twibe'],
#  ['thenewbnb',
#   'dun',
#   'tell',
#   'me',
#   'come',
#   'it',
#   'wud',
#   'be',
#   'fun',
#   'we',
#   'will',
#   'have',
#   'a',
#   'mast',
#   'wala',
#   'tweetup'],
#  ['hm', 'today', 'already', 'kind', 'of', 'sucks'],
#  ['chilling', 'watching', 'the', 'television'],
#  ['am', 'updates', 'in', 'twitter', 'stats'],
#  ['she', 'll', 'be', 'staying', 'the', 'night', 'though'],
#  ['plastic', 'aida', 'results', 'in', 'ouchies', 'for', 'my', 'fingers'],
#  ['rockinaround', 'nope', 'don', 't', 'you', 'think', 'it', 's', 'a', 'crime'],
#  ['evey',
#   'definately',
#   'garver',
#   'is',
#   'yummy',
#   'too',
#   'got',
#   'something',
#   'of',
#   'a',
#   'thing',
#   'for',
#   'older',
#   'men'],
#  ['potato',
#   'tacos',
#   'gerry',
#   'nicoles',
#   'pad',
#   'amp',
#   'watched',
#   'a',
#   'japanese',
#   'coachroach',
#   'anime',
#   'the',
#   'perfect',
#   'marriage',
#   'lol'],
#  ['only', 'my', 'half', 'hehe'],
#  ['wendy_munro',
#   'i',
#   'really',
#   'miss',
#   'working',
#   'hate',
#   'not',
#   'having',
#   'anything',
#   'do',
#   'always',
#   'been',
#   'studying',
#   'or',
#   'working',
#   'another'],
#  ['ahhhhh',
#   'really',
#   'slept',
#   'in',
#   'today',
#   'am',
#   'and',
#   'now',
#   'having',
#   'breakfast',
#   'then',
#   'working',
#   'on',
#   'stupid',
#   'book',
#   'report',
#   'with',
#   'son',
#   'and',
#   'making',
#   'spoon',
#   'pupet'],
#  ['manicmai',
#   'oooh',
#   'lol',
#   'let',
#   'me',
#   'know',
#   'of',
#   'the',
#   'time',
#   'venue',
#   'and',
#   'all'],
#  ['nickkkjonasss', 'i', 'like', 'poison', 'ivy', 'the', 'best'],
#  ['sarma',
#   'a',
#   'summer',
#   'internship',
#   'would',
#   'be',
#   'awesome',
#   'i',
#   'm',
#   'free',
#   'and',
#   'don',
#   't',
#   'have',
#   'to',
#   'teach',
#   'again',
#   'until',
#   'august',
#   'th',
#   'where',
#   'do',
#   'i',
#   'sign',
#   'up'],
#  ['jessicalynn',
#   'jessica',
#   'your',
#   'friends',
#   'should',
#   'get',
#   'twitter',
#   'too'],
#  ['haaaaaaaaaaaaircut', 'tomorrow'],
#  ['serafinowicz',
#   'twitpic',
#   'com',
#   'wx',
#   'apologies',
#   'for',
#   'the',
#   'last',
#   'comment',
#   'i',
#   'cant',
#   'delete',
#   'it',
#   'and',
#   'it',
#   'seems',
#   'like',
#   'its',
#   'earned',
#   'me',
#   'a',
#   'blocking'],
#  ['i',
#   'm',
#   'updating',
#   'my',
#   'twitter',
#   'from',
#   'the',
#   'kitchen',
#   'this',
#   'i',
#   'awesome'],
#  ['watching',
#   'keeping',
#   'up',
#   'with',
#   'the',
#   'kardashians',
#   'and',
#   'going',
#   'on',
#   'gaiaonline',
#   'how',
#   'fun'],
#  ['reszzpati',
#   'hiya',
#   'where',
#   'are',
#   'you',
#   'now',
#   'mia_r',
#   'talithaxoxo',
#   'btw',
#   'i',
#   'also',
#   'used',
#   'to',
#   'watch',
#   'f',
#   'i',
#   'was',
#   'a',
#   'fan',
#   'of',
#   'vic',
#   'zhou',
#   'haha'],
#  ['soooooooo', 'bored', 'now', 'i', 'have', 'something', 'to', 'do', 'bye'],
#  ['we',
#   're',
#   'off',
#   'to',
#   'moon',
#   'palace',
#   'resort',
#   'punta',
#   'cana',
#   'dominican',
#   'republic',
#   'for',
#   'day',
#   'all',
#   'expense',
#   'paid',
#   'for',
#   'two',
#   'by',
#   'our',
#   'company',
#   'www',
#   'bizforfamilies',
#   'com'],
#  ['that',
#   'interview',
#   'went',
#   'so',
#   'well',
#   'i',
#   'think',
#   'that',
#   'job',
#   'is',
#   'mine'],
#  ['why',
#   'am',
#   'tipsy',
#   'at',
#   'in',
#   'the',
#   'afternoon',
#   'thanks',
#   'theresa',
#   'sad',
#   'u',
#   'r',
#   'leaving'],
#  ['you',
#   'must',
#   'live',
#   'in',
#   'or',
#   'near',
#   'leeds',
#   'and',
#   'be',
#   'willing',
#   'to',
#   'help',
#   'out',
#   'if',
#   'required',
#   'but',
#   'it',
#   's',
#   'not',
#   'expected',
#   'message',
#   'me',
#   'with',
#   'why',
#   'i',
#   'should',
#   'choose',
#   'you'],
#  ['totz', 'using', 'the', 'computer', 'at', 'tafe', 'theres', 'one', 'btw'],
#  ['thanktank',
#   'thank',
#   'you',
#   'also',
#   'i',
#   'have',
#   'met',
#   'some',
#   'wonderful',
#   'nice',
#   'tweeples',
#   'on',
#   'twitter',
#   'amp',
#   'a',
#   'thank',
#   'you',
#   'is',
#   'long',
#   'overdue',
#   'to',
#   'them'],
#  ['jinglis',
#   'thanks',
#   'i',
#   'm',
#   'a',
#   'newbie',
#   'at',
#   'the',
#   'webdesign',
#   'thing',
#   'but',
#   'it',
#   'kind',
#   'of',
#   'fun'],
#  ['jefferycjordan',
#   'yeah',
#   'i',
#   'am',
#   'pretty',
#   'tired',
#   'it',
#   's',
#   'just',
#   'so',
#   'hard',
#   'to',
#   'fall',
#   'asleep',
#   'in',
#   'someone',
#   'elses',
#   'bed',
#   'amp',
#   'not',
#   'your',
#   'own'],
#  ['is',
#   'having',
#   'dinner',
#   'pork',
#   'amp',
#   'beans',
#   'plurk',
#   'com',
#   'p',
#   'p',
#   'x'],
#  ['sweetkittie',
#   'if',
#   'u',
#   'get',
#   'over',
#   'followers',
#   'every',
#   'will',
#   'think',
#   'you',
#   'are',
#   'a',
#   'celebrity'],
#  ['school',
#   'today',
#   'which',
#   'i',
#   'am',
#   'not',
#   'looking',
#   'forward',
#   'to',
#   'then',
#   'soccer',
#   'and',
#   'dancing',
#   'with',
#   'the',
#   'stars'],
#  ['ifernando',
#   'wahay',
#   'fast',
#   'forward',
#   'has',
#   'problems',
#   'on',
#   'my',
#   'copy'],
#  ['robert_terpstra',
#   'i',
#   'guess',
#   'you',
#   'have',
#   'that',
#   'india',
#   'call',
#   'daily',
#   'huh',
#   'i',
#   'work',
#   'with',
#   'brazil',
#   'so',
#   'no',
#   'timezone',
#   'issues'],
#  ['if',
#   'you',
#   'build',
#   'it',
#   'nerds',
#   'will',
#   'come',
#   'from',
#   'benchwarmers',
#   'favmoviequote'],
#  ['not', 'gon', 'na', 'see', 'tsonga', 'on', 'final'],
#  ['mmm',
#   'reconsituted',
#   'meat',
#   'products',
#   'and',
#   'week',
#   'old',
#   'veggies',
#   'got',
#   'ta',
#   'love',
#   'that',
#   'rehydrated',
#   'warm',
#   'milk',
#   'for',
#   'breakfast'],
#  ['still',
#   'sick',
#   'i',
#   'blame',
#   'lpena',
#   'for',
#   'my',
#   'voice',
#   'being',
#   'gone'],
#  ['x_maxine_x',
#   'aha',
#   'same',
#   'i',
#   'dont',
#   'think',
#   'il',
#   'manage',
#   'this',
#   'all',
#   'nighter',
#   'al',
#   'fall',
#   'asleep',
#   'at',
#   'the',
#   'laptop',
#   'no',
#   'doubt',
#   'amp'],
#  ['auditiondanny',
#   'that',
#   'game',
#   'was',
#   'reediculous',
#   'i',
#   'm',
#   'glad',
#   'ozzy',
#   'got',
#   'a',
#   'blow',
#   'out'],
#  ['capcom_unity',
#   'no',
#   'sadly',
#   'i',
#   'couldn',
#   't',
#   'go',
#   'to',
#   'e',
#   'this',
#   'year'],
#  ['alright',
#   'twit',
#   'luvs',
#   'i',
#   'got',
#   'ta',
#   'throw',
#   'in',
#   'the',
#   'towel',
#   'good',
#   'nite',
#   'u',
#   'all',
#   'and',
#   'if',
#   'i',
#   'cld',
#   'rly',
#   'get',
#   'down',
#   'and',
#   'pray',
#   'i',
#   'wld',
#   'but',
#   'have',
#   'a',
#   'safe',
#   'night'],
#  ['trvsbrkr',
#   'markhoppus',
#   'tomdelonge',
#   'curse',
#   'not',
#   'getting',
#   'paid',
#   'for',
#   'a',
#   'week',
#   'i',
#   'was',
#   'forced',
#   'to',
#   'get',
#   'lawn',
#   'seats',
#   'to',
#   'sit',
#   'forever',
#   'away'],
#  ['not',
#   'feeling',
#   'very',
#   'good',
#   'at',
#   'all',
#   'why',
#   'does',
#   'this',
#   'have',
#   'to',
#   'happen',
#   'today',
#   'of',
#   'all',
#   'days',
#   'not',
#   'going',
#   'to',
#   'friends',
#   'tonight'],
#  ['barbedwyer', 'thank', 'you', 'smiles', 'back', 'to', 'you', 'too'],
#  ['i', 'came', 'her', 'to', 'make', 'you', 'dance', 'tonight'],
#  ['flavianalin',
#   'ainda',
#   'nao',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day',
#   'seb',
#   'day'],
#  ['claueekenobi', 'yeah', 'it', 's', 'raining', 'so', 'hard', 'right', 'now'],
#  ['caitlingray',
#   'i',
#   'don',
#   't',
#   'get',
#   'how',
#   'they',
#   're',
#   'funny',
#   'please',
#   'explain',
#   'lol'],
#  ['williamstanton', 'yay', 'first', 'tweet', 'haha'],
#  ['wmacgyver',
#   'indeed',
#   'i',
#   'believe',
#   'it',
#   'to',
#   'be',
#   'an',
#   'omen',
#   'don',
#   't',
#   'you',
#   'think',
#   'so'],
#  ['haha',
#   'i',
#   'found',
#   'a',
#   'cheap',
#   'hair',
#   'extension',
#   'in',
#   'my',
#   'wardrobe',
#   'so',
#   'now',
#   'i',
#   'have',
#   'an',
#   'extra',
#   'long',
#   'plait',
#   'today',
#   'i',
#   'm',
#   'so',
#   'freezing',
#   'cold',
#   'seriously'],
#  ['laying',
#   'down',
#   'got',
#   'out',
#   'of',
#   'work',
#   'for',
#   'couple',
#   'hours',
#   'nap',
#   'time',
#   'sleepy',
#   'and',
#   'sick'],
#  ['i',
#   'am',
#   'hanging',
#   'with',
#   'my',
#   'bestestestest',
#   'firned',
#   'in',
#   'the',
#   'whole',
#   'entire',
#   'worldd',
#   'be',
#   'superly',
#   'duperly',
#   'jealouss'],
#  ['i',
#   'm',
#   'home',
#   'i',
#   'm',
#   'exhausted',
#   'amp',
#   'still',
#   'have',
#   'hang',
#   'over',
#   'headache',
#   'ugh'],
#  ['ivanae', 'im', 'dead', 'too', 'lol', 'couldnt', 'sleep'],
#  ['gazomatik',
#   'i',
#   'know',
#   'we',
#   'should',
#   'go',
#   'lunch',
#   'someday',
#   'fool',
#   'and',
#   'costco'],
#  ['well',
#   'i',
#   'most',
#   'definitely',
#   'have',
#   'a',
#   'broken',
#   'heart',
#   'no',
#   'use',
#   'pining',
#   'but',
#   'damn',
#   'it',
#   'why',
#   'do',
#   'good',
#   'things',
#   'have',
#   'to',
#   'go',
#   'bad'],
#  ['wow',
#   'today',
#   'has',
#   'been',
#   'a',
#   'great',
#   'day',
#   'for',
#   'being',
#   'monday'],
#  ['unexploded_yet',
#   'yeah',
#   'i',
#   'could',
#   'use',
#   'some',
#   'right',
#   'about',
#   'now'],
#  ['christosdiam',
#   'well',
#   'i',
#   'know',
#   'i',
#   'would',
#   'be',
#   'pretty',
#   'sad',
#   'if',
#   'i',
#   'didn',
#   't',
#   'have',
#   'good',
#   'sex',
#   'in',
#   'my',
#   'life',
#   'but',
#   'happiness',
#   'good',
#   'qust',
#   'what',
#   'is',
#   'good',
#   'sex'],
#  ['seen',
#   'yest',
#   'today',
#   'still',
#   'on',
#   'mc',
#   'but',
#   'got',
#   'to',
#   'come',
#   'back'],
#  ['sitting',
#   'at',
#   'cheeseburger',
#   'waikiki',
#   'in',
#   'you',
#   'guessed',
#   'it',
#   'waikiki'],
#  ['spencerkat',
#   'a',
#   'truck',
#   'full',
#   'of',
#   'gum',
#   'balls',
#   'i',
#   'likes',
#   'it'],
#  ['jgoreham',
#   'yeah',
#   'it',
#   's',
#   'so',
#   'frustrating',
#   'man',
#   'but',
#   'i',
#   'used',
#   'to',
#   'do',
#   'the',
#   'same',
#   'myself',
#   'only',
#   'because',
#   'i',
#   'was',
#   'jealous',
#   'amp',
#   'living',
#   'in',
#   'such',
#   'a',
#   'shit',
#   'country'],
#  ['lenswithlove', 'twuv', 'amp', 'twugs'],
#  ['more', 'days', 'to', 'cold', 'turkey', 'plurk', 'com', 'p', 'p', 'g', 'k'],
#  ['watching',
#   'the',
#   'e',
#   'true',
#   'hollywood',
#   'story',
#   'of',
#   'heath',
#   'ledger'],
#  ['workplacecoach',
#   'get',
#   'followers',
#   'a',
#   'day',
#   'using',
#   'www',
#   'tweeteradder',
#   'once',
#   'you',
#   'add',
#   'everyone',
#   'you',
#   'are',
#   'on',
#   'the',
#   'train',
#   'or',
#   'pay',
#   'vip'],
#  ['at',
#   'bdubs',
#   'for',
#   'hot',
#   'tech',
#   'guys',
#   'going',
#   'away',
#   'party',
#   'erica'],
#  ['_superhuman',
#   'lol',
#   'cool',
#   'im',
#   'not',
#   'doing',
#   'much',
#   'did',
#   'you',
#   'end',
#   'up',
#   'getting',
#   'through',
#   'i',
#   'never',
#   'get',
#   'through',
#   'and',
#   'it',
#   'really',
#   'sucks'],
#  ['at',
#   'work',
#   'but',
#   'only',
#   'thinking',
#   'about',
#   'our',
#   'trip',
#   'to',
#   'chicago',
#   'so',
#   'excited',
#   'to',
#   'take',
#   'the',
#   'kids',
#   'to',
#   'rainforest',
#   'cafe',
#   'tonight'],
#  ['nancydee_online',
#   'i',
#   'thought',
#   'you',
#   'were',
#   'ms',
#   'it',
#   'you',
#   'need',
#   'a',
#   'man',
#   's',
#   'touch'],
#  ['melpenny',
#   'got',
#   'ta',
#   'do',
#   'some',
#   'graft',
#   'tomorrow',
#   'and',
#   'sunday',
#   'and',
#   'in',
#   'between',
#   'that',
#   'i',
#   'm',
#   'gon',
#   'na',
#   'try',
#   'to',
#   'eat',
#   'biltong',
#   'easily',
#   'pleased'],
#  ['why',
#   'are',
#   'all',
#   'strange',
#   'men',
#   'adding',
#   'me',
#   'on',
#   'facebook',
#   'is',
#   'it',
#   'because',
#   'i',
#   'am',
#   'listed',
#   'as',
#   'married',
#   'there'],
#  ['tantantiniiin',
#   'yes',
#   'unfortunately',
#   'they',
#   'found',
#   'him',
#   'in',
#   'his',
#   'bed',
#   'this',
#   'morning'],
#  ['saw',
#   'sumwhere',
#   'b',
#   'i',
#   'n',
#   'g',
#   'bing',
#   'is',
#   'not',
#   'google',
#   'now',
#   'that',
#   'is',
#   'coool'],
#  ['backstreetboys',
#   'please',
#   'twitt',
#   'mee',
#   'say',
#   'hi',
#   'paola',
#   'brian',
#   'plase'],
#  ['apparently',
#   'lebron',
#   'james',
#   'is',
#   'being',
#   'named',
#   'the',
#   'nba',
#   'mvp',
#   'dang',
#   'i',
#   'had',
#   'my',
#   'on',
#   'zach',
#   'randolph'],
#  ['dinner', 'baseball', 'game', 'then', 'caitlyns'],
#  ['luigimasi', 'please', 'take', 'me', 'to', 'x', 'factor'],
#  ['jonaskevin',
#   'are',
#   'you',
#   'mocking',
#   'miley',
#   'that',
#   's',
#   'not',
#   'nice',
#   'of',
#   'you'],
#  ['loves', 'her', 'david', 'soooooo', 'much', 'lt'],
#  ['home',
#   'with',
#   'a',
#   'moody',
#   'year',
#   'old',
#   'in',
#   'tow',
#   'got',
#   'ta',
#   'make',
#   'dinner',
#   'now',
#   'for',
#   'the',
#   'mr'],
#  ['turkishoney', 'heeey', 'gary', 'wie', 'geehts'],
#  ['tommcfly',
#   'twitpic',
#   'com',
#   'g',
#   'n',
#   'this',
#   'one',
#   'we',
#   'get',
#   'a',
#   'close',
#   'up',
#   'on',
#   'ur',
#   'face'],
#  ['sad',
#   'that',
#   'i',
#   'm',
#   'not',
#   'going',
#   'pub',
#   'quiz',
#   'boozing',
#   'again',
#   'this',
#   'week',
#   'will',
#   'have',
#   'to',
#   'settle',
#   'for',
#   'a',
#   'bottle',
#   'of',
#   'ale',
#   'and',
#   'a',
#   'movie'],
#  ['off',
#   'to',
#   'get',
#   'pancakes',
#   'late',
#   'night',
#   'food',
#   'of',
#   'champions',
#   'have',
#   'to',
#   'get',
#   'to',
#   'the',
#   'car',
#   'first'],
#  ['beta', 'painless', 'upgrade'],
#  ['watching',
#   'one',
#   'tree',
#   'hill',
#   'my',
#   'poor',
#   'kitten',
#   'has',
#   'to',
#   'get',
#   'surgery'],
#  ['leaves',
#   'for',
#   'ny',
#   'on',
#   'wednesday',
#   'i',
#   'need',
#   'to',
#   'find',
#   'time',
#   'between',
#   'work',
#   'sleep',
#   'and',
#   'feeling',
#   'sick',
#   'to',
#   'start',
#   'packing',
#   'i',
#   'can',
#   't',
#   'wait',
#   'to',
#   'see',
#   'my',
#   'family'],
#  ['joyburst', 'someone', 'is', 'going', 'twitted', 'happy'],
#  ['had',
#   'a',
#   'great',
#   'saturday',
#   'first',
#   'session',
#   'at',
#   'am',
#   'clear',
#   'blue',
#   'sky',
#   'and',
#   'big',
#   'smile'],
#  ['i',
#   'wan',
#   'na',
#   'be',
#   'with',
#   'you',
#   'kristin',
#   'my',
#   'mommys',
#   'being',
#   'mean',
#   'to',
#   'me'],
#  ['baronvonmolden',
#   'the',
#   'aconcagua',
#   'in',
#   'jan',
#   'so',
#   'will',
#   'be',
#   'now',
#   'preparing',
#   'for',
#   'that',
#   'one',
#   'just',
#   'had',
#   'a',
#   'week',
#   'or',
#   'rest',
#   'after',
#   'last',
#   'one',
#   'thanks',
#   'for',
#   'sponsor'],
#  ['www', 'yourebeautifulwoman', 'is', 'live', 'take', 'a', 'sneak', 'peak'],
#  ['sunburns', 'suck'],
#  ['petshopboys',
#   'i',
#   'downloaded',
#   'one',
#   'of',
#   'the',
#   'bundles',
#   'yesterday',
#   'unfortunately',
#   'in',
#   'ireland',
#   'it',
#   'was',
#   'â',
#   'but',
#   'still',
#   'worth',
#   'it'],
#  ['kitchenpuppies', 'can', 't', 'wait', 'to', 'see', 'your', 'brioche'],
#  ['arien',
#   'lizziehalfpenny',
#   'abbie_judd',
#   'oh',
#   'bugger',
#   'servers',
#   'down',
#   'all',
#   'sites',
#   'have',
#   'been',
#   'transferred',
#   'except',
#   'mine'],
#  ['sarahbitch', 'what', 'omg', 'noo'],
#  ['jjfanshawe', 'my', 'parents', 'are', 'here'],
#  ['jennl',
#   'but',
#   'sometimes',
#   'it',
#   'doesn',
#   't',
#   'show',
#   'when',
#   'my',
#   'tweets',
#   'reply',
#   'to',
#   'me'],
#  ['watching', 'the', 'hangover', 'caint', 'wait'],
#  ['frikkin',
#   'starving',
#   'and',
#   'wants',
#   'food',
#   'now',
#   'edmonton',
#   'still',
#   'coming',
#   'home',
#   'tomorrow',
#   'and',
#   'i',
#   'hope',
#   'lucky',
#   'is',
#   'okay',
#   'and',
#   'sasha',
#   'isn',
#   't',
#   'too',
#   'lonely',
#   'w',
#   'o',
#   'her'],
#  ['so',
#   'the',
#   'power',
#   'cable',
#   'from',
#   'the',
#   'psu',
#   'to',
#   'the',
#   'mobo',
#   'is',
#   'fried',
#   'i',
#   'found',
#   'of',
#   'the',
#   'pins',
#   'were',
#   'black',
#   'great'],
#  ['dysenterypinky',
#   'well',
#   'they',
#   'don',
#   't',
#   'tour',
#   'here',
#   'in',
#   'europe',
#   'i',
#   'live',
#   'in',
#   'germany',
#   'i',
#   'hope',
#   'they',
#   'come',
#   'next',
#   'year'],
#  ['preparin',
#   'for',
#   'the',
#   'stupid',
#   'media',
#   'exam',
#   'good',
#   'luckk',
#   'peopless',
#   'xx'],
#  ['wants', 'a', 'muffin'],
#  ['grudge',
#   'noises',
#   'with',
#   'brookaayy',
#   'and',
#   'lucakhouri',
#   'welcome',
#   'to',
#   'our',
#   'daily',
#   'weird',
#   'convos',
#   'lucino'],
#  ['you',
#   'can',
#   'say',
#   'it',
#   'all',
#   'you',
#   'want',
#   'but',
#   'actions',
#   'speak',
#   'louder',
#   'than',
#   'words',
#   'darling'],
#  ['lol',
#   'nancydee_online',
#   'u',
#   'tell',
#   'him',
#   'girl',
#   'haha',
#   'u',
#   'put',
#   'damondcclark',
#   'in',
#   'his',
#   'place',
#   'lol',
#   'ouch'],
#  ['chipotle', 'before', 'the', 'show'],
#  ['nitchola',
#   'is',
#   'going',
#   'back',
#   'to',
#   'his',
#   'mom',
#   'today',
#   'which',
#   'means',
#   'im',
#   'all',
#   'alone',
#   'again',
#   'here',
#   'we',
#   're',
#   'gon',
#   'na',
#   'have',
#   'breakfast',
#   'in',
#   'the',
#   'nature',
#   'reserve',
#   'first',
#   'tho'],
#  ['happy', 'birthday', 'to', 'my', 'little', 'sis'],
#  ['lizzie',
#   'x',
#   'he',
#   'so',
#   'should',
#   'i',
#   'll',
#   'ask',
#   'him',
#   'cos',
#   'you',
#   'know',
#   'he',
#   's',
#   'never',
#   'been',
#   'asked',
#   'that',
#   'before'],
#  ['katchin',
#   'ykyat',
#   'com',
#   'n',
#   'p',
#   'oooh',
#   'that',
#   'is',
#   'a',
#   'good',
#   'idea'],
#  ['jessicaenright',
#   'i',
#   'm',
#   'probably',
#   'going',
#   'to',
#   'take',
#   'him',
#   'to',
#   'the',
#   'strawberry',
#   'festival'],
#  ['my', 'lucky', 'batman', 'ink', 'pen', 'has', 'run', 'out', 'of', 'ink'],
#  ['is', 'sooo', 'sleepy', 'and', 'doesn', 't', 'want', 'to', 'work', 'today'],
#  ['psychobel',
#   'you',
#   'know',
#   'you',
#   'love',
#   'it',
#   'saw',
#   'buda',
#   'last',
#   'night',
#   'had',
#   'a',
#   'fab',
#   'curry',
#   'good',
#   'chat',
#   'will',
#   'meet',
#   'up',
#   'next',
#   'week',
#   'small',
#   'world'],
#  ['just',
#   'when',
#   'i',
#   'thought',
#   'it',
#   's',
#   'over',
#   'i',
#   'm',
#   'glad',
#   'i',
#   'still',
#   'have',
#   'you',
#   'granny'],
#  ['ice', 'cream', 'is', 'always', 'a', 'win'],
#  ['hitechhall',
#   'i',
#   'love',
#   'the',
#   'site',
#   'what',
#   'a',
#   'hoot',
#   'really',
#   'enjoy',
#   'the',
#   'hair',
#   'cuts',
#   'in',
#   'thailand',
#   'always',
#   'try',
#   'to',
#   'time',
#   'ir',
#   'just',
#   'right',
#   'thanks',
#   'for',
#   'the',
#   'tip'],
#  ['sunday', 'sessh'],
#  ['i',
#   've',
#   'been',
#   'disrespectful',
#   'to',
#   'my',
#   'hero',
#   'sorry',
#   'andyjustus'],
#  ['headed',
#   'to',
#   'the',
#   'beach',
#   'for',
#   'my',
#   'last',
#   'full',
#   'day',
#   'on',
#   'the',
#   'sun'],
#  ['pottan',
#   'twitpic',
#   'com',
#   'rv',
#   'h',
#   'so',
#   'are',
#   'you',
#   'planning',
#   'to',
#   'take',
#   'the',
#   'sticker',
#   'of',
#   'quot',
#   'best',
#   'of',
#   'e',
#   'quot',
#   'home'],
#  ['i',
#   'got',
#   'every',
#   'tv',
#   'on',
#   'tuned',
#   'into',
#   'my',
#   'band',
#   'there',
#   's',
#   'a',
#   'lil',
#   'bit',
#   'of',
#   'a',
#   'delay',
#   'in',
#   'the',
#   'office'],
#  ['kissysellout', 'i', 'would', 'but', 'i', 've', 'been', 'banned'],
#  ['wish',
#   'i',
#   'had',
#   'more',
#   'time',
#   'to',
#   'tweet',
#   'off',
#   'to',
#   'pick',
#   'up',
#   'twins',
#   'then',
#   'shopping',
#   'special',
#   'request',
#   'for',
#   'pasta',
#   'amp',
#   'meatballs',
#   'for',
#   'tea',
#   'from',
#   'thomas'],
#  ['you',
#   'do',
#   'do',
#   'alot',
#   'for',
#   'me',
#   'low',
#   'key',
#   'i',
#   'guess',
#   'thats',
#   'why',
#   'i',
#   'dont',
#   'get',
#   'upset',
#   'when',
#   'you',
#   'complain',
#   'over',
#   'everything',
#   'lol'],
#  ['pearl_roob',
#   'yes',
#   'b',
#   'is',
#   'good',
#   'you',
#   'know',
#   'it',
#   's',
#   'a',
#   'bad',
#   'read',
#   'if',
#   'i',
#   'graded',
#   'it',
#   'c',
#   'or',
#   'below'],
#  ['home',
#   'folders',
#   'offline',
#   'files',
#   'and',
#   'folder',
#   'names',
#   'sorry',
#   'if',
#   'the',
#   'topic',
#   'is',
#   'a',
#   'bit',
#   'ambiguous',
#   'but',
#   'i',
#   'have',
#   'questions',
#   'tinyurl',
#   'com',
#   'pxvhb'],
#  ['lstacey',
#   'will',
#   'do',
#   'when',
#   'my',
#   'websites',
#   'finished',
#   'it',
#   's',
#   'covers',
#   'but',
#   'eh'],
#  ['ericahudson', 'ha', 'ha', 'and', 'you', 'watched', 'me'],
#  ['going',
#   'home',
#   'i',
#   'hate',
#   'this',
#   'i',
#   'just',
#   'feel',
#   'like',
#   'nothing',
#   'is',
#   'going',
#   'right'],
#  ['bryonyrocks',
#   'inooo',
#   'i',
#   'so',
#   'cant',
#   'afford',
#   'it',
#   'but',
#   'need',
#   'some',
#   'been',
#   'lookin',
#   'on',
#   'the',
#   'internet',
#   'but',
#   'you',
#   'have',
#   'to',
#   'buy',
#   'in',
#   'bulk',
#   'so',
#   'its',
#   'well',
#   'expensive'],
#  ['im',
#   'bored',
#   'idk',
#   'just',
#   'made',
#   'a',
#   'facebook',
#   'follow',
#   'me',
#   'with',
#   'cecily',
#   'and',
#   'kayla'],
#  ['lowridergrl',
#   'i',
#   'bet',
#   'when',
#   'is',
#   'he',
#   'supposed',
#   'to',
#   'come',
#   'home'],
#  ['shaunarawrr_x', 'same', 'i', 'm', 'on', 'the', 'go', 'today'],
#  ['theres', 'no', 'easy', 'way', 'to', 'deal', 'with', 'losing', 'someone'],
#  ['chicmommyusa',
#   'too',
#   'bad',
#   'we',
#   'can',
#   't',
#   'blip',
#   'here',
#   'sigh',
#   'hope',
#   'to',
#   'have',
#   'some',
#   'time',
#   'later',
#   'at',
#   'home'],
#  ['gooodmorningg',
#   'and',
#   'happy',
#   'mother',
#   's',
#   'day',
#   'to',
#   'anyone',
#   'that',
#   's',
#   'a',
#   'mama',
#   'churrrchhh',
#   'tiiiimmeee'],
#  ['very',
#   'annoyed',
#   'with',
#   'reality',
#   'tv',
#   'max',
#   'was',
#   'one',
#   'of',
#   'my',
#   'favoritesss',
#   'are',
#   'there',
#   'even',
#   'any',
#   'male',
#   'ballroom',
#   'dancers',
#   'left'],
#  ['is', 'going', 'to', 'have', 'a', 'nephew', 'aww'],
#  ['teaching', 'grandpa', 'how', 'to', 'use', 'his', 'new', 'macbook'],
#  ['no', 'good', 'movies', 'on', 't', 'v', 'sweet', 'dreams', 'y', 'all'],
#  ['im',
#   'about',
#   'to',
#   'leave',
#   'in',
#   'a',
#   'few',
#   'wish',
#   'me',
#   'luck',
#   'tomorrow',
#   'today',
#   'was',
#   'an',
#   'awkward',
#   'day',
#   'in',
#   'to',
#   'many',
#   'ways',
#   'byeee'],
#  ['awesome',
#   'group',
#   'bit',
#   'ly',
#   's',
#   'd',
#   'repost',
#   'this',
#   'tweet',
#   'for',
#   'me',
#   'please'],
#  ['damienfranco',
#   'its',
#   'so',
#   'common',
#   'for',
#   'it',
#   'to',
#   'crash',
#   'now',
#   'i',
#   'find',
#   'i',
#   'have',
#   'to',
#   'delete',
#   'the',
#   'process',
#   'then',
#   'its',
#   'ok',
#   'again',
#   'for',
#   'a',
#   'while',
#   'its',
#   'eating',
#   'memory'],
#  ['i',
#   'swear',
#   'its',
#   'so',
#   'hot',
#   'i',
#   'dont',
#   'want',
#   'to',
#   'leave',
#   'my',
#   'house',
#   'is',
#   'it',
#   'hot',
#   'where',
#   'your',
#   'at'],
#  ['mad', 'that', 'he', 'has', 'to', 'go', 'i', 'dnt', 'want', 'him', 'to'],
#  ['i', 'accidentally', 'reformatted', 'my', 'hard', 'drive', 'oops'],
#  ['missladyluv',
#   'that',
#   's',
#   'tonight',
#   'aww',
#   'man',
#   'i',
#   'm',
#   'missing',
#   'it'],
#  ['our',
#   'friend',
#   's',
#   'year',
#   'old',
#   'grandfather',
#   'got',
#   'hit',
#   'by',
#   'a',
#   'car',
#   'while',
#   'crossing',
#   'the',
#   'street',
#   'a',
#   'few',
#   'days',
#   'ago',
#   'in',
#   'hawthorne',
#   'may',
#   'his',
#   'soul',
#   'rest',
#   'in',
#   'peace'],
#  ['back', 'from', 'history', 'exam', 'went', 'okayish', 'i', 'suppose'],
#  ['i',
#   've',
#   'been',
#   'studying',
#   'for',
#   'almost',
#   'hours',
#   'straight',
#   'i',
#   'can',
#   't',
#   'do',
#   'it',
#   'anymore'],
#  ['started',
#   'to',
#   'fall',
#   'asleep',
#   'then',
#   'gg',
#   'starts',
#   'grunting',
#   'for',
#   'me'],
#  ['and', 'this', 'friggen', 'music', 'is', 'pissing', 'us', 'off', 'grrr'],
#  ['sophiafoots', 'no', 'i', 'hope', 'she', 'comes', 'home', 'very', 'soon'],
#  ['twitpic',
#   'com',
#   'ss',
#   'q',
#   'paulaabdul',
#   'paula',
#   'i',
#   'think',
#   'miley',
#   'is',
#   'wearing',
#   'your',
#   'quot',
#   'shinning',
#   'armor',
#   'quot',
#   'ring',
#   'in',
#   'this',
#   'pic'],
#  ['awaits',
#   'the',
#   'verdict',
#   'on',
#   'the',
#   'wellbeing',
#   'of',
#   'her',
#   'desktop',
#   'mobo'],
#  ['luv',
#   'livnlaf',
#   'of',
#   'modern',
#   'burlesque',
#   'is',
#   'crap',
#   'the',
#   'men',
#   'acted',
#   'the',
#   'same',
#   'way',
#   'back',
#   'then',
#   'as',
#   'they',
#   'do',
#   'now',
#   'though',
#   'art',
#   'or',
#   'not'],
#  ['thunder',
#   'storms',
#   'scare',
#   'me',
#   'when',
#   'i',
#   'm',
#   'alone',
#   'i',
#   'll',
#   'be',
#   'hiding',
#   'under',
#   'my',
#   'covers',
#   'if',
#   'you',
#   'need',
#   'me'],
#  ['overg',
#   'i',
#   'guess',
#   'a',
#   'quot',
#   'quot',
#   'would',
#   'have',
#   'been',
#   'better'],
#  ['officially',
#   'on',
#   'board',
#   'the',
#   'carnval',
#   'glory',
#   'see',
#   'you',
#   'in',
#   'a',
#   'week',
#   'twitter'],
#  ['had', 'a', 'not', 'so', 'good', 'day'],
#  ['can',
#   'not',
#   'wait',
#   'to',
#   'go',
#   'back',
#   'to',
#   'bkk',
#   'the',
#   'country',
#   'of',
#   'nightlife',
#   'and',
#   'the',
#   'sun',
#   'freed',
#   'from',
#   'all',
#   'those',
#   'cloudy',
#   'and',
#   'rainy',
#   'environment'],
#  ['god', 'is', 'so', 'good'],
#  ['old',
#   'there',
#   'i',
#   'said',
#   'it',
#   'can',
#   't',
#   'hang',
#   'like',
#   'i',
#   'used',
#   'to'],
#  ['patron',
#   'ace',
#   'of',
#   'spaid',
#   'last',
#   'night',
#   'paying',
#   'for',
#   'it',
#   'today',
#   'so',
#   'hung',
#   'over'],
#  ['miamii', 'oh', 'ok', 'can', 't', 'or', 'just', 'don', 't', 'want', 'to'],
#  ['melissaegilbert',
#   'i',
#   'know',
#   'all',
#   'about',
#   'hair',
#   'with',
#   'its',
#   'own',
#   'personality',
#   'when',
#   'unleashed',
#   'except',
#   'i',
#   'have',
#   'no',
#   'curl',
#   'it',
#   'just',
#   'flops'],
#  ['n',
#   'y',
#   'senators',
#   'polled',
#   'on',
#   'marriage',
#   'vote',
#   'only',
#   'of',
#   'stand',
#   'for',
#   'marriage',
#   'equality',
#   'tinyurl',
#   'com',
#   'pvykn'],
#  ['haha', 'never', 'missed', 'it', 'thank', 'god'],
#  ['getting',
#   'ready',
#   'to',
#   'go',
#   'to',
#   'the',
#   'car',
#   'boot',
#   'sale',
#   'hope',
#   'i',
#   'find',
#   'some',
#   'junk',
#   'so',
#   'tired',
#   'though'],
#  ['xcrepsley',
#   'hm',
#   'i',
#   'don',
#   't',
#   'but',
#   'it',
#   's',
#   'okay',
#   'i',
#   'why',
#   'don',
#   't',
#   'we',
#   'talk',
#   'anymore'],
#  ['moving', 'in', 'the', 'morning', 'i', 'cant', 'believe', 'it'],
#  ['i',
#   'still',
#   'can',
#   't',
#   'understand',
#   'why',
#   'windows',
#   'is',
#   'so',
#   'popular',
#   'i',
#   've',
#   'been',
#   'sitting',
#   'here',
#   'for',
#   'minutes',
#   'waiting',
#   'for',
#   'it',
#   'to',
#   'finish',
#   'charring',
#   'up',
#   'my',
#   'hdd'],
#  ['good', 'nite', 'and', 'good', 'mornin', 'to', 'some', 'of', 'ya'],
#  ['god',
#   'i',
#   'really',
#   'want',
#   'a',
#   'fat',
#   'blunt',
#   'right',
#   'now',
#   'but',
#   'i',
#   'don',
#   't'],
#  ['up',
#   'and',
#   'getting',
#   'ready',
#   'for',
#   'a',
#   'new',
#   'day',
#   'vacation',
#   'is',
#   'over'],
#  ['ebassman',
#   'so',
#   'rob',
#   'and',
#   'fish',
#   'want',
#   'to',
#   'come',
#   'to',
#   'alaska',
#   'what',
#   'about',
#   'you',
#   'it',
#   'was',
#   'degrees',
#   'today',
#   'so',
#   'it',
#   's',
#   'not',
#   'cold',
#   'lol'],
#  ['at',
#   'the',
#   'clouds',
#   'and',
#   'the',
#   'threat',
#   'of',
#   'rain',
#   'in',
#   'savusavu'],
#  ['mrs_nickj',
#   'i',
#   'm',
#   'watching',
#   'a',
#   'taylor',
#   'swift',
#   'nbc',
#   'special',
#   'but',
#   'i',
#   'missed',
#   'half',
#   'of',
#   'it'],
#  ['i',
#   'm',
#   'in',
#   'the',
#   'mood',
#   'to',
#   'get',
#   'things',
#   'done',
#   'right',
#   'now',
#   'i',
#   'want',
#   'to',
#   'take',
#   'advantage',
#   'of',
#   'this',
#   'rare',
#   'early',
#   'morning',
#   'feeling',
#   'but',
#   'everything',
#   'is',
#   'closed'],
#  ['theroser',
#   'when',
#   'you',
#   'guys',
#   'come',
#   'to',
#   'washington',
#   'state',
#   'you',
#   'should',
#   'totally',
#   'crush',
#   'that',
#   'tacoma',
#   'mall',
#   'please',
#   'lol'],
#  ['oh',
#   'damn',
#   'promised',
#   'my',
#   'dad',
#   'i',
#   'd',
#   'leave',
#   'skype',
#   'open',
#   'and',
#   'i',
#   'forgot',
#   'and',
#   'they',
#   'actually',
#   'left',
#   'me',
#   'a',
#   'message'],
#  ['peaceoutl',
#   'ur',
#   'n',
#   'oh',
#   'i',
#   'm',
#   'sry',
#   'yeah',
#   'i',
#   'did',
#   'it',
#   'was',
#   'the',
#   'one',
#   'titled',
#   'viena',
#   'ty',
#   'and',
#   'mike',
#   'were',
#   'talking',
#   'about',
#   'where',
#   'they',
#   'r',
#   'and',
#   'some',
#   'other',
#   'stuff'],
#  ['therealmahogany',
#   'nuttin',
#   'boo',
#   'u',
#   'be',
#   'neglectin',
#   'me',
#   'and',
#   'shit'],
#  ['oh',
#   'noooo',
#   'runaway',
#   'jury',
#   'is',
#   'on',
#   'i',
#   'wan',
#   'na',
#   'watch',
#   'it',
#   'but',
#   'i',
#   'need',
#   'to',
#   'go',
#   'to',
#   'bed'],
#  ['shyat',
#   'webcam',
#   'with',
#   'soon',
#   'me',
#   'as',
#   'soon',
#   'as',
#   'you',
#   'get',
#   'your',
#   'internet',
#   'and',
#   'whatnot',
#   'established',
#   'i',
#   'm',
#   'gon',
#   'na',
#   'miss',
#   'all',
#   'the',
#   'stupid',
#   'things',
#   'we',
#   'do'],
#  ['not', 'even', 'cherry', 'on', 'top', 'made', 'this', 'night', 'better'],
#  ['mia_r',
#   'i',
#   'was',
#   'bitten',
#   'years',
#   'ago',
#   'i',
#   'm',
#   'def',
#   'a',
#   'night',
#   'person',
#   'why',
#   'it',
#   's',
#   'summer',
#   'amp',
#   'i',
#   'have',
#   'nothing',
#   'better',
#   'to',
#   'do',
#   'lol'],
#  ['wow',
#   'where',
#   'did',
#   'the',
#   'day',
#   'go',
#   'ah',
#   'well',
#   'work',
#   'tomorrow',
#   'wait',
#   'a',
#   'minute',
#   'i',
#   'don',
#   't',
#   'i',
#   'm',
#   'on',
#   'vacation',
#   'roll',
# ...
#   'the',
#   'sims',
#   'it',
#   's',
#   'the',
#   'only',
#   'video',
#   'game',
#   'i',
#   'like',
#   'i',
#   'm',
#   'jealous'],
#  ['suffering', 'tweetdeck', 'withdrawl'],
#  ['only',
#   'in',
#   'frm',
#   'wrk',
#   'i',
#   'm',
#   'a',
#   'bit',
#   'bored',
#   'wif',
#   'nufin',
#   'do',
#   'n',
#   'cnt',
#   'sleep'],
#  ['dbigwoo', 'thanks', 'for', 'that', 'idea', 'right', 'before', 'bed'],
#  ['ryan', 's', 'amp', 'is', 'getting', 'fixed', 'the', 'transformer', 'broke'],
#  ['khushee',
#   'yeah',
#   'it',
#   'is',
#   'i',
#   'found',
#   'someone',
#   'that',
#   'may',
#   'interest',
#   'you',
#   'i',
#   'am',
#   'following',
#   'him',
#   'we',
#   'can',
#   'raise',
#   'awareness',
#   'will',
#   'pass',
#   'you',
#   'd',
#   'password',
#   'for',
#   'fct'],
#  ['anystab',
#   'i',
#   'know',
#   'what',
#   'you',
#   'feel',
#   'right',
#   'now',
#   'everything',
#   'will',
#   'be',
#   'fine'],
#  ['off', 'to', 'work', 'in', 'a', 'bit', 'please', 'no', 'more', 'rain'],
#  ['ccristinaa',
#   'both',
#   'of',
#   'them',
#   'cause',
#   'there',
#   'both',
#   'equally',
#   'awesome'],
#  ['doesntfeelwell'],
#  ['marcelz',
#   'yes',
#   'it',
#   'is',
#   'because',
#   'she',
#   'don',
#   't',
#   'understand',
#   'english'],
#  ['vinaygmurthy', 'nice', 'would', 'have', 'loved', 'to', 'be', 'there'],
#  ['sad',
#   'face',
#   'all',
#   'my',
#   'pictures',
#   'are',
#   'too',
#   'big',
#   'for',
#   'twitter'],
#  ['krisytan',
#   'rkexperience',
#   'it',
#   'wasn',
#   't',
#   'as',
#   'bad',
#   'as',
#   'i',
#   'thought',
#   'and',
#   'i',
#   'get',
#   'to',
#   'be',
#   'next',
#   'to',
#   'you'],
#  ['boostmobile',
#   'you',
#   're',
#   'in',
#   'irvine',
#   'any',
#   'perks',
#   'for',
#   'us',
#   'residents',
#   'here'],
#  ['the',
#   'dj',
#   'hero',
#   'release',
#   'party',
#   'on',
#   'monday',
#   'was',
#   'awsome',
#   'but',
#   'y',
#   'did',
#   'a',
#   'stranger',
#   'hug',
#   'me',
#   'lol',
#   'but',
#   'it',
#   'stil',
#   'rocked'],
#  ['annaw',
#   'thats',
#   'deffo',
#   'the',
#   'real',
#   'miley',
#   'shes',
#   'even',
#   'said',
#   'on',
#   'interviews',
#   'tht',
#   'its',
#   'her'],
#  ['chapped',
#   'lips',
#   'i',
#   'wish',
#   'i',
#   'knew',
#   'where',
#   'my',
#   'burt',
#   's',
#   'bees',
#   'was'],
#  ['mr_marty', 'haha', 'we', 'shall', 'keep', 'score'],
#  ['tipsbynate',
#   'hi',
#   'thx',
#   'for',
#   'following',
#   'i',
#   'teach',
#   'some',
#   'chinese',
#   'lessons',
#   'on',
#   'youtube',
#   'pls',
#   'feel',
#   'free',
#   'to',
#   'have',
#   'a',
#   'look',
#   'www',
#   'youtube',
#   'com',
#   'chineselearn'],
#  ['nando', 's', 'clears', 'the', 'sinuses'],
#  ['missjperez',
#   'bad',
#   'i',
#   'know',
#   'so',
#   'i',
#   'just',
#   'ducked',
#   'down',
#   'and',
#   'drove',
#   'on',
#   'past'],
#  ['abcmsaj',
#   'mine',
#   'seems',
#   'ok',
#   'so',
#   'that',
#   's',
#   'where',
#   'you',
#   've',
#   'gone'],
#  ['wow',
#   'two',
#   'hugs',
#   'in',
#   'two',
#   'days',
#   'spent',
#   'the',
#   'day',
#   'in',
#   'reading',
#   'yesterday',
#   'had',
#   'a',
#   'good',
#   'chinwag'],
#  ['is', 'home', 'but', 'leaving', 'for', 'over', 'a', 'week', 'morrow'],
#  ['just', 'going', 'to', 'shop', 'brb'],
#  ['sooo',
#   'tired',
#   'studying',
#   'again',
#   'then',
#   'off',
#   'to',
#   'bed',
#   'math',
#   'exam',
#   'in',
#   'the',
#   'morning'],
#  ['victoriagrace',
#   'i',
#   'm',
#   'ok',
#   'my',
#   'dad',
#   'has',
#   'sick',
#   'the',
#   'past',
#   'couple',
#   'weeks',
#   'but',
#   'is',
#   'coming',
#   'home',
#   'soon',
#   'finally',
#   'hope',
#   'you',
#   'are',
#   'doing',
#   'better'],
#  ['akarmin',
#   'no',
#   'i',
#   'didnt',
#   'because',
#   'i',
#   'cant',
#   'read',
#   'my',
#   'dms',
#   'on',
#   'my',
#   'phone'],
#  ['housework', 'sucks', 'but', 'hey', 'it', 'has', 'to', 'be', 'done'],
#  ['photobucket', 'time', 'yes', 'be', 'scared', 'jbpo'],
#  ['regigigas_',
#   'i',
#   'wish',
#   'you',
#   'still',
#   'did',
#   'your',
#   'raves',
#   'on',
#   'land',
#   'i',
#   'liked',
#   'going',
#   'to',
#   'them'],
#  ['danmikhael',
#   'is',
#   'a',
#   'hoser',
#   'i',
#   'am',
#   'most',
#   'definitely',
#   'human',
#   'and',
#   'have',
#   'a',
#   'sneaky',
#   'suspicion',
#   'that',
#   'dan',
#   'has',
#   'quot',
#   'ego',
#   'quot',
#   'issues',
#   'posted',
#   'links',
#   'you',
#   'chill',
#   'geek'],
#  ['callie',
#   'we',
#   've',
#   'had',
#   'thunderstorms',
#   'all',
#   'week',
#   'and',
#   'most',
#   'of',
#   'last',
#   'i',
#   'don',
#   't',
#   'think',
#   'the',
#   'twitter',
#   'outage',
#   'is',
#   'related',
#   'just',
#   'a',
#   'hunch'],
#  ['trevoralgatt',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'follow',
#   'and',
#   'thank',
#   'you',
#   'for',
#   'reading',
#   'my',
#   'article',
#   'it',
#   'is',
#   'inspiring',
#   'to',
#   'hear',
#   'from',
#   'readers',
#   'keeps',
#   'me',
#   'going'],
#  ['lithousewife',
#   'i',
#   'missed',
#   'all',
#   'the',
#   'fun',
#   'nat',
#   'book',
#   'fest',
#   'here',
#   'we',
#   'come'],
#  ['missfiasco',
#   'hell',
#   'no',
#   'they',
#   'don',
#   't',
#   'i',
#   'had',
#   'a',
#   'memory',
#   'card',
#   'but',
#   'i',
#   'l',
#   'st',
#   'it',
#   'all',
#   'bd',
#   'if',
#   'you',
#   'see',
#   'any',
#   'pixx',
#   'of',
#   'me',
#   'i',
#   'm',
#   'sorry',
#   'lhh'],
#  ['off',
#   'back',
#   'to',
#   'aberaeron',
#   'now',
#   'long',
#   'journey',
#   'but',
#   'worth',
#   'it',
#   'for',
#   'mum',
#   's',
#   'birthday',
#   'amp',
#   'fathers',
#   'day',
#   'cards',
#   'presents',
#   'havent',
#   'arrived',
#   'in',
#   'the',
#   'post',
#   'yet'],
#  ['danengland',
#   'nope',
#   'not',
#   'to',
#   'live',
#   'just',
#   'for',
#   'three',
#   'weeks',
#   'for',
#   'my',
#   'daddy',
#   's',
#   'wedding',
#   'you',
#   'should',
#   'come',
#   'down',
#   'with',
#   'the',
#   'wifey',
#   'and',
#   'see',
#   'us'],
#  ['legsvampiri', 'aw', 'i', 'want', 'to', 'see', 'them', 'so', 'much'],
#  ['there', 's', 'no', 'internet', 'access', 'at', 'the', 'new', 'place'],
#  ['neonmanda', 'how', 'are', 'you'],
#  ['ad',
#   'sugarsync',
#   'now',
#   'has',
#   'support',
#   'for',
#   'blackberry',
#   'as',
#   'well',
#   'it',
#   's',
#   'perfect',
#   'for',
#   'busy',
#   'execs',
#   'all',
#   'files',
#   'on',
#   'the',
#   'go',
#   'is',
#   'gd',
#   'qe',
#   'j'],
#  ['you',
#   'know',
#   'that',
#   'i',
#   'could',
#   'use',
#   'somebody',
#   'someone',
#   'like',
#   'you'],
#  ['darn',
#   'it',
#   'my',
#   'phone',
#   's',
#   'dying',
#   'it',
#   's',
#   'making',
#   'that',
#   'noise',
#   'totally',
#   'sounds',
#   'like',
#   'it',
#   's',
#   'in',
#   'pain',
#   'wounded',
#   'solider'],
#  ['therealtiffany',
#   'me',
#   'too',
#   'the',
#   'gym',
#   'always',
#   'makes',
#   'you',
#   'feel',
#   'better'],
#  ['is',
#   'at',
#   'the',
#   'office',
#   'fell',
#   'back',
#   'asleep',
#   'this',
#   'morning',
#   'oops'],
#  ['spent',
#   'all',
#   'day',
#   'waiting',
#   'for',
#   'electricity',
#   'to',
#   'come',
#   'now',
#   'it',
#   'has',
#   'come',
#   'i',
#   'am',
#   'really',
#   'tired',
#   'and',
#   'have',
#   'to',
#   'go',
#   'sleep'],
#  ['this',
#   'boy',
#   'i',
#   'like',
#   'thinks',
#   'i',
#   'm',
#   'cute',
#   'and',
#   'i',
#   'like',
#   'it',
#   'a',
#   'lot',
#   'oh',
#   'and',
#   'him',
#   'i',
#   'like',
#   'him',
#   'a',
#   'lot',
#   'too'],
#  ['divinelycrazy',
#   'yeah',
#   'i',
#   'know',
#   'i',
#   'really',
#   'hope',
#   'you',
#   're',
#   'better'],
#  ['kept',
#   'walking',
#   'around',
#   'singapore',
#   'today',
#   'and',
#   'more',
#   'to',
#   'come',
#   'tomorrow',
#   'and',
#   'on',
#   'tuesday',
#   'and',
#   'even',
#   'on',
#   'the',
#   'day',
#   'of',
#   'our',
#   'flight'],
#  ['donlemoncnn',
#   'have',
#   'fun',
#   'here',
#   'it',
#   's',
#   'a',
#   'little',
#   'chilly',
#   'live',
#   'in',
#   'ma',
#   'we',
#   'haven',
#   't',
#   'had',
#   'a',
#   'spring',
#   'whatsoever'],
#  ['ah',
#   'well',
#   'oh',
#   'dear',
#   'i',
#   'think',
#   'i',
#   'will',
#   'miss',
#   'polly',
#   'quite',
#   'a',
#   'lot',
#   'this',
#   'week'],
#  ['so',
#   'soon',
#   'friday',
#   'partaaaay',
#   'shame',
#   'about',
#   'alice',
#   'not',
#   'being',
#   'able',
#   'to',
#   'come'],
#  ['had', 'a', 'great', 'day', 'playing', 'rock', 'band'],
#  ['jpmarth', 'rss', 'd', 'awesome', 'pictures', 'very', 'inspiring'],
#  ['janda',
#   'love',
#   'to',
#   'hear',
#   'your',
#   'thoughts',
#   'of',
#   'the',
#   'new',
#   'lp',
#   'i',
#   'don',
#   't',
#   'have',
#   'it',
#   'myself',
#   'prefer',
#   'classic',
#   'bob',
#   'to',
#   'modern',
#   'bob',
#   'lol'],
#  ['greedy_yearning', 'hey', 'how', 'are', 'you'],
#  ['mitchelmusso',
#   'loved',
#   'the',
#   'music',
#   'videoo',
#   'and',
#   'the',
#   'song',
#   'i',
#   'cant',
#   'wait',
#   'for',
#   'ur',
#   'new',
#   'album',
#   'to',
#   'come',
#   'out'],
#  ['finals', 'week', 'shoot', 'me', 'now'],
#  ['watching',
#   'my',
#   'favorite',
#   'show',
#   'muneca',
#   'brava',
#   'i',
#   'hate',
#   'this',
#   'episode'],
#  ['hello',
#   'konichiwa',
#   'hola',
#   'i',
#   'about',
#   'to',
#   'go',
#   'to',
#   'church',
#   'sunday',
#   'school',
#   'and',
#   'i',
#   'gon',
#   'na',
#   'eat',
#   'pancakes',
#   'again',
#   'at',
#   'a',
#   'awesome',
#   'favorite',
#   'pancake',
#   'house'],
#  ['looking',
#   'forward',
#   'to',
#   'sunday',
#   's',
#   'game',
#   'lady',
#   'aztecs',
#   'playing',
#   'for',
#   'rd',
#   'place',
#   'if',
#   'they',
#   'had',
#   'only',
#   'won',
#   'penalty',
#   'kicks'],
#  ['danu_mc',
#   'yea',
#   'its',
#   'worth',
#   'it',
#   'but',
#   'its',
#   'not',
#   'like',
#   'she',
#   'answered'],
#  ['mcawilliams', 'it', 'll', 'be', 'mobile', 'unfriendly', 'though'],
#  ['hating',
#   'that',
#   'i',
#   'm',
#   'sick',
#   'amp',
#   'my',
#   'sister',
#   's',
#   'in',
#   'icu',
#   'but',
#   'i',
#   'm',
#   'loving',
#   'the',
#   'paid',
#   'vacay',
#   'from',
#   'work'],
#  ['twitpic', 'com', 'djt', 'me', 'in', 'my', 'national', 'costume'],
#  ['timberwolf',
#   'so',
#   'she',
#   's',
#   'having',
#   'surgery',
#   'and',
#   'chris',
#   'is',
#   'really',
#   'upset',
#   'will',
#   'keep',
#   'you',
#   'updated',
#   'though',
#   'and',
#   'talk',
#   'to',
#   'you',
#   'next',
#   'week',
#   'love',
#   'you',
#   'xx'],
#  ['so',
#   'kinda',
#   'bored',
#   'wan',
#   'na',
#   'drink',
#   'wan',
#   'na',
#   'smoke',
#   'nothing',
#   'i',
#   'm',
#   'running',
#   'outta',
#   'cigs',
#   'and',
#   'money',
#   'fast',
#   'i',
#   'suck',
#   'right'],
#  ['hours',
#   'until',
#   'the',
#   'boss',
#   'hits',
#   'the',
#   'stage',
#   'live',
#   'broadcast',
#   'on',
#   'the',
#   'web',
#   'pinkpopmashup',
#   'vpro',
#   'nl',
#   'pp',
#   'pp'],
#  ['twitpic',
#   'com',
#   'on',
#   'o',
#   'my',
#   'awesome',
#   'broken',
#   'cell',
#   'phone',
#   'camera'],
#  ['kaatje_',
#   'create',
#   'you',
#   'go',
#   'away',
#   'for',
#   'a',
#   'minute',
#   'and',
#   'you',
#   'guys',
#   'start',
#   'talking',
#   'about',
#   'deleting',
#   'again',
#   'i',
#   'waz',
#   'just',
#   'orderin',
#   'a',
#   'movie',
#   'honest'],
#  ['i',
#   'seriously',
#   'freaking',
#   'hate',
#   'labels',
#   'especially',
#   'towards',
#   'girls',
#   'just',
#   'because',
#   'a',
#   'girl',
#   'is',
#   'sexy',
#   'and',
#   'confident',
#   'with',
#   'themselfs',
#   'they',
#   'are',
#   'wh',
#   's',
#   'wtf'],
#  ['astroboyisgay', 'ok', 'i', 'will', 'thanks'],
#  ['metal',
#   'miguel',
#   'te',
#   'amo',
#   'sorry',
#   'i',
#   'couldnt',
#   'make',
#   'it',
#   'i',
#   'll',
#   'make',
#   'it',
#   'up',
#   'to',
#   'u',
#   'promise',
#   'and',
#   'i',
#   'll',
#   'give',
#   'u',
#   'a',
#   'wittle',
#   'gift',
#   'p',
#   'wittle',
#   'me',
#   'no',
#   'got',
#   'money'],
#  ['petnanny',
#   'no',
#   'you',
#   're',
#   'not',
#   'the',
#   'only',
#   'one',
#   'i',
#   'd',
#   'never',
#   'dress',
#   'my',
#   'dog',
#   'up',
#   'he',
#   'looks',
#   'lovely',
#   'as',
#   'he',
#   'is'],
#  ['saroe',
#   'aww',
#   'im',
#   'sorry',
#   'boo',
#   'did',
#   'you',
#   'put',
#   'a',
#   'bandaid',
#   'on',
#   'it'],
#  ['a_spastic_tiger',
#   'wee',
#   'in',
#   'the',
#   'bath',
#   'come',
#   'on',
#   'we',
#   'all',
#   'let',
#   'a',
#   'little',
#   'out'],
#  ['wants',
#   'demi',
#   'lovato',
#   'to',
#   'be',
#   'the',
#   'opening',
#   'act',
#   'for',
#   'jo',
#   'bros',
#   'world',
#   'tour',
#   'th',
#   'nov'],
#  ['feel',
#   'much',
#   'better',
#   'than',
#   'yesterday',
#   'it',
#   'wasn',
#   't',
#   'swine',
#   'flu'],
#  ['hmm',
#   'what',
#   'to',
#   'do',
#   'go',
#   'online',
#   'in',
#   'ym',
#   'maybe',
#   'not',
#   'go',
#   'to',
#   'sleep',
#   'after',
#   'santinno',
#   'sure',
#   'im',
#   'lazy',
#   'today'],
#  ['alaide', 'me', 'neither'],
#  ['got', 'woken', 'up', 'with', 'a', 'kiss', 'this', 'morning'],
#  ['i', 'want', 'the', 'sun', 'to', 'come', 'back'],
#  ['sitting',
#   'here',
#   'at',
#   'work',
#   'waiting',
#   'for',
#   'this',
#   'visit',
#   'would',
#   'like',
#   'to',
#   'go',
#   'home',
#   'and',
#   'sleep',
#   'off',
#   'this',
#   'sickness'],
#  ['blackcalalilly', 'sorry', 'for', 'beating', 'u', 'lol'],
#  ['fincey', 'i', 'miss', 'you'],
#  ['yeaaaaaa', 'cavs'],
#  ['dreabean',
#   'i',
#   'think',
#   'of',
#   'you',
#   'everytime',
#   'too',
#   'i',
#   'miss',
#   'everything',
#   'we',
#   'just',
#   'entered',
#   'ohio',
#   'you',
#   'know',
#   'i',
#   'll',
#   'be',
#   'there'],
#  ['is', 'getting', 'ready', 'to', 'go', 'out', 'w', 't'],
#  ['fashnsswthrt', 'yep', 'definitely'],
#  ['miamiadc', 'good', 'morning'],
#  ['with', 'all', 'things', 'to', 'catch', 'up', 'in', 'school'],
#  ['i',
#   'can',
#   'not',
#   'stand',
#   'windows',
#   'lotus',
#   'notes',
#   'or',
#   'our',
#   'it',
#   'department',
#   'one',
#   'moment',
#   'longer',
#   'it',
#   'fail'],
#  ['happy', 'mother', 's', 'day', 'to', 'all', 'you', 'mamas', 'out', 'there'],
#  ['got',
#   'ta',
#   'go',
#   'to',
#   'sleep',
#   'i',
#   'can',
#   't',
#   'resist',
#   'more',
#   'xddd',
#   'see',
#   'ya',
#   'tomorrow',
#   'twitterssss'],
#  ['vanda_long',
#   'are',
#   'you',
#   'too',
#   'far',
#   'gone',
#   'on',
#   'the',
#   'right',
#   'to',
#   'ever',
#   'go',
#   'left'],
#  ['har',
#   'har',
#   'swineflu',
#   'is',
#   'everywhere',
#   'twitpic',
#   'com',
#   'jb',
#   'o',
#   'via',
#   'kaihellyeah'],
#  ['is',
#   'upset',
#   'that',
#   'h',
#   'amp',
#   'm',
#   'is',
#   'not',
#   'coming',
#   'to',
#   'singaporeee'],
#  ['followfriday',
#   'rocketrobin',
#   'he',
#   's',
#   'the',
#   'dude',
#   'and',
#   'straight',
#   'on',
#   'the',
#   'buzzer',
#   'vote',
#   'for',
#   'julian',
#   'smith',
#   'amp',
#   'his',
#   'sexy',
#   'sax',
#   'x'],
#  ['ah', 'i', 'feel', 'bad', 'for', 'one', 'of', 'my', 'friends'],
#  ['natiest', 'thanks', 'chicka'],
#  ['is', 'sunburnt', 'i', 'hate', 'the', 'sun'],
#  ['amarie',
#   'yay',
#   'can',
#   't',
#   'wait',
#   'to',
#   'come',
#   'visit',
#   'speaking',
#   'of',
#   'visit',
#   'the',
#   'bbq',
#   'is',
#   'planned',
#   'for',
#   'july',
#   'th'],
#  ['jonathanrknight',
#   'thank',
#   'u',
#   'sweetie',
#   'can',
#   't',
#   'wait',
#   'to',
#   'set',
#   'sail',
#   'with',
#   'u',
#   'next',
#   'week'],
#  ['binnyva', 'tht', 'time', 'it', 'tff', 'goes', 'unknown', 'filetype'],
#  ['fun',
#   'fact',
#   'guys',
#   'and',
#   'dolls',
#   'was',
#   'awesome',
#   'and',
#   'lauren',
#   'graham',
#   'can',
#   'sing',
#   'now',
#   'getting',
#   'psyched',
#   'for',
#   'game',
#   'of',
#   'pens',
#   'wings',
#   'got',
#   'home',
#   'just',
#   'in',
#   'time'],
#  ['is', 'smiling', 'at', 'how', 'amazing', 'this', 'weekend', 'was'],
#  ['therealbanner',
#   'let',
#   's',
#   'see',
#   'f',
#   't',
#   'w',
#   'd',
#   'rubbin',
#   'my',
#   'chin',
#   'hmmmm',
#   'i',
#   'know',
#   'i',
#   'know',
#   'it',
#   's',
#   'quot',
#   'for',
#   'the',
#   'world',
#   'dammit',
#   'quot',
#   'lol',
#   'sounds',
#   'like',
#   'a',
#   'hit',
#   'to',
#   'me'],
#  ['i', 'm', 'still', 'really', 'really', 'tired'],
#  ['going', 'to', 'the', 'dentist'],
#  ['neffytabor',
#   'cool',
#   'there',
#   'are',
#   'many',
#   'other',
#   'websites',
#   'affiliated',
#   'with',
#   'it',
#   'so',
#   'it',
#   's',
#   'possible',
#   'to',
#   'get',
#   'a',
#   'fair',
#   'amount',
#   'back'],
#  ['chevale',
#   'what',
#   'did',
#   'u',
#   'do',
#   'today',
#   'yeah',
#   'me',
#   'too',
#   'i',
#   'hate',
#   'headache',
#   'might',
#   'sleep',
#   'early',
#   'tonight',
#   'and',
#   'internet',
#   'is',
#   'crazy',
#   'again'],
#  ['iambynoe',
#   'dang',
#   'my',
#   'cousin',
#   'gets',
#   'love',
#   'b',
#   'i',
#   'do',
#   'smh',
#   'i',
#   'thought',
#   'you',
#   'was',
#   'my',
#   'boo'],
#  ['now', 'in', 'the', 'netherlands', 'shopping'],
#  ['sipping',
#   'mint',
#   'tea',
#   'still',
#   'nauseous',
#   'will',
#   'try',
#   'to',
#   'get',
#   'to',
#   'bed',
#   'early',
#   'tonight'],
#  ['is', 'hunggry'],
#  ['jessemccartney', 'i', 'am', 'your', 'biggest', 'fan'],
#  ['these',
#   'days',
#   'have',
#   'been',
#   'looking',
#   'better',
#   'better',
#   'betterrrrrrrr'],
#  ['today', 'i', 'see', 'my', 'family', 'it', 'will', 'be', 'a', 'good', 'day'],
#  ['at',
#   'home',
#   'watching',
#   'mini',
#   's',
#   'first',
#   'time',
#   'nikki',
#   'reed',
#   'is',
#   'amazing'],
#  ['fuckimtwitting',
#   'haha',
#   'i',
#   'was',
#   'thinking',
#   'of',
#   'long',
#   'and',
#   'blonde'],
#  ['veilin',
#   'i',
#   'love',
#   'you',
#   'more',
#   'more',
#   'more',
#   'now',
#   'you',
#   'can',
#   'cut',
#   'it',
#   'out'],
#  ['hungwee',
#   'again',
#   'thinking',
#   'of',
#   'the',
#   'massive',
#   'pancakes',
#   'i',
#   'saw',
#   'at',
#   'the',
#   'menu',
#   'yday'],
#  ...]

# %%
txt_sal = [stem_and_lemmatize(tw) for tw in txt_tkn]
text_processed = [remove_stopwords(tw) for tw in txt_sal]
text_processed

# %%
text['text_processed'] = text_processed

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# your code here
from sklearn.feature_extraction.text import TfidfVectorizer

bow_vect = TfidfVectorizer(max_features=5000)
bow_vect.fit(text['text_processed'])

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
